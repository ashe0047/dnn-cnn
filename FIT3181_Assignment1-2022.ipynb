# %% [markdown]
# # <span style="color:#0b486b">  FIT3181: Deep Learning (2022)</span>
# ***
# *CE/Lecturer:* Dr **Trung Le** | trunglm@monash.edu <br/>
# *Head Tutor:* Mr **Thanh Nguyen** | thanh.nguyen4@monash.edu  <br/>
# <br/>
# Department of Data Science and AI, Faculty of Information Technology, Monash University, Australia
# ***

# %% [markdown]
# # <span style="color:#0b486b">  Student Information</span>
# ***
# Surname: **[Aw]**  <br/>
# Firstname: **[Sheng Xiang]**    <br/>
# Student ID: **[31259030]**    <br/>
# Email: **[ashe0047@student.monash.edu]**    <br/>
# Your tutorial time: **[Tuesday 9AM]**    <br/>
# ***

# %% [markdown]
# # <span style="color:#0b486b">Deep Neural Networks</span>
# ### Due: <span style="color:red">11:59pm Sunday, 18 September 2022</span>  (Sunday)
#
# #### <span style="color:red">Important note:</span> This is an **individual** assignment. It contributes **20%** to your final mark. Read the assignment instruction carefully.

# %% [markdown]
# ## <span style="color:#0b486b">Instruction</span>
#
# This notebook has been prepared for your to complete Assignment 1. The theme of this assignment is about practical machine learning knowledge and skills in deep neural networks, including feedforward and convolutional neural networks. Some sections have been partially completed to help you get
# started. **The total marks for this notebook is 100**.
#
# * Before you start, read the entire notebook carefully once to understand what you need to do. <br/>
#
# * For each cell marked with **#YOU ARE REQUIRED TO INSERT YOUR CODES IN THIS CELL**, there will be places where you **must** supply your own codes when instructed. <br>
#
# This assignment contains **three** parts:
#
# * Part 1: Questions on theory and knowledge on machine learning and deep learning **[30 points], 30%**
# * Part 2: Coding assessment on TensorFlow for Deep Neural Networks (DNN) **[30 points], 30%**
# * Part 3: Coding assessment on TensorFlow for Convolution Neural Networks (CNN) **[40 points], 40%**
#
# **Hint**: This assignment was essentially designed based on the lectures and tutorials sessions covered from Week 1 to Week 6. You are strongly recommended to go through these contents thoroughly which might help you to complete this assignment.

# %% [markdown]
# ## <span style="color:#0b486b">What to submit</span>
#
# This assignment is to be completed individually and submitted to Moodle unit site. **By the due date, you are required to submit one  <span style="color:red; font-weight:bold">single zip file, named xxx_assignment01_solution.zip</span> where `xxx` is your student ID, to the corresponding Assignment (Dropbox) in Moodle**.

# %% [markdown]
# ***For example, if your student ID is <span style="color:red; font-weight:bold">12356</span>, then gather all of your assignment solution to folder, create a zip file named <span style="color:red; font-weight:bold">123456_assignment01_solution.zip</span> and submit this file.***

# %% [markdown]
# Within this zip folder, you **must** submit the following files:
# 1.	**Assignment01_solution.ipynb**:  this is your Python notebook solution source file.
# 1.	**Assignment01_output.html**: this is the output of your Python notebook solution *exported* in html format.
# 1.	Any **extra files or folder** needed to complete your assignment (e.g., images used in your answers).

# %% [markdown]
# Since the notebook is quite big to load and work together, one recommended option is to split solution into three parts and work on them seperately. In that case, replace **Assignment01_solution.ipynb** by three notebooks: **Assignment01_Part1_solution.ipynb**, **Assignment01_Part2_solution.ipynb** and **Assignment01_Part3_solution.ipynb**

# %% [markdown]
# **You can run your codes on Google Colab. In this case, you need to capture the screenshots of your Google Colab model training and put in corresponding places in your Jupyter notebook. You also need to store your trained models to folder <span style="color:red; font-weight:bold">*./models*</span> with recognizable file names (e.g., Part3_Sec3_2_model.h5).**

# %% [markdown]
# ## <span style="color:#0b486b">Part 1: Theory and Knowledge Questions</span>
# <div style="text-align: right"><span style="color:red; font-weight:bold">[Total marks for this part: 30 points]<span></div>

# %% [markdown]
# The first part of this assignment is for you to demonstrate your knowledge in deep learning that you have acquired from the lectures and tutorials materials. Most of the contents in this assignment are drawn from **the lectures and tutorials from weeks 1 to 3**. Going through these materials before attempting this part is highly recommended.

# %% [markdown]
# ####  <span style="color:red">**Question 1.1**</span> **Activation function plays an important role in modern Deep NNs. For each of the activation function below, state its output range, find its derivative (show your steps), and plot the activation function and its derivative**
#
# <span style="color:red">**(a)**</span> Leaky ReLU: $\text{LeakyReLU}\left(x\right)=\begin{cases}
# 0.01x & \text{if}\,x<0\\
# x & \text{otherwise}
# \end{cases}$
# <div style="text-align: right"><span style="color:red">[1.5 points]</span></div>
#
# <span style="color:red">**(b)**</span> Softplus: $\text{Softplus}\left(x\right)=\text{ln}\left(1+e^{x}\right)$
# <div style="text-align: right"><span style="color:red">[1.5 points]</span></div>

# %% [markdown]
# <span style="color:red">**(a)**</span><br>
# Output Range: $$ 0 < LeakyReLU < 0.01 $$
# Let $L = LeakyReLU(x)$ <br>
# $$\frac{dL}{dx} = \begin{cases}
# 0.01 & \text{if}\,x<0\\
# 1 & \text{otherwise}
# \end{cases}$$
#
#
# <span style="color:red">**(b)**</span>
# Output Range: $$ Softplus(x) \geqslant 0 $$
# Let $S = Softplus(x)$ <br>
# $$\frac{dS}{dx} = \frac{1}{1+\exp^x} = \frac{\exp^x}{1+\exp^x} $$

# %% [markdown]
# <span style="color:#0b486b"> **Numpy is possibly being used in the following questions. You need to import numpy here.** </span>

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ####  <span style="color:red">**Question 1.2**</span> **Assume that we feed a data point $x$ with a ground-truth label $y=2$ to the feed-forward neural network with the ReLU activation function as shown in the following figure**
# <img src="Figures/Q2_P1.png" width="500" align="center"/>
#
#
# <span style="color:red">**(a)**</span>  What is the numerical value of the latent presentation $h^1(x)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>
#
# <span style="color:red">**(b)**</span>  What is the numerical value of the latent presentation $h^2(x)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>
#
# <span style="color:red">**(c)**</span>  What is the numerical value of the logit $h^3(x)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>
#
# <span style="color:red">**(d)**</span>  What is the corresonding prediction probabilities $p(x)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>
#
# <span style="color:red">**(e)**</span>  What is the cross-entropy loss caused by the feed-forward neural network at $(x,y)$? Remind that $y=2$.
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>
#
# <span style="color:red">**(f)**</span>  Assume that we are applying the label smoothing technique (i.e.,  [link for main paper](https://papers.nips.cc/paper/2019/file/f1748d6b0fd9d439f71450117eba2725-Paper.pdf) from Goeff Hinton) with $\alpha = 0.1$. What is the relevant loss caused by the feed-forward neural network at $(x,y)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>
#
#
# **You need to show both formulas and numerical results for earning full mark. Although it is optional, it is great if you show your numpy code for your computation.**

# %% [markdown]
# > ### Answer:
# <span style="color:blue">**(a)**</span><br>
# $$x = \begin{bmatrix}
#    1 \\
#    -1 \\
#    1
# \end{bmatrix},
# W_1 =
# \begin{bmatrix}
#    1&-1&1 \\
#    1&-1&-1 \\
#    2&-1&2 \\
#    -1&-2&1 \\
# \end{bmatrix},
# b_1 =
# \begin{bmatrix}
#    1 \\
#    0 \\
#    1 \\
#    0
# \end{bmatrix}$$
# $$ h^1(x) =
# \begin{bmatrix}
#    1&-1&1 \\
#    1&-1&-1 \\
#    2&-1&2 \\
#    -1&-2&1 \\
# \end{bmatrix}
# \begin{bmatrix}
#    1 \\
#    -1 \\
#    1
# \end{bmatrix}
# +
# \begin{bmatrix}
#    1 \\
#    0 \\
#    1 \\
#    0
# \end{bmatrix} =
# \begin{bmatrix}
#    4 \\
#    1 \\
#    6 \\
#    2
# \end{bmatrix}$$

# %% [markdown]
# <span style="color:blue">**(b)**</span><br>
# $$h^1(x) = \begin{bmatrix}
#    4 \\
#    1 \\
#    6 \\
#    2
# \end{bmatrix},
# W_2 =
# \begin{bmatrix}
#    1&-1&-1&2 \\
#    1&-1&1&-1 \\
#    -1&2&-1&2 \\
# \end{bmatrix},
# b_2 =
# \begin{bmatrix}
#    1 \\
#    1 \\
#    0
# \end{bmatrix}$$
# $$ h^2(x) =
# \begin{bmatrix}
#    1&-1&-1&2 \\
#    1&-1&1&-1 \\
#    -1&2&-1&2 \\
# \end{bmatrix}
# \begin{bmatrix}
#    4 \\
#    1 \\
#    6 \\
#    2
# \end{bmatrix}
# +
# \begin{bmatrix}
#    1 \\
#    1 \\
#    0
# \end{bmatrix} =
# \begin{bmatrix}
#    2 \\
#    8 \\
#    -4
# \end{bmatrix}$$

# %% [markdown]
# <span style="color:blue">**(c)**</span><br>
# $$h^2(x) = \begin{bmatrix}
#    2 \\
#    8 \\
#    -4
# \end{bmatrix},
# W_3 =
# \begin{bmatrix}
#    1&-2&1 \\
#    1&2&-1 \\
#    -1&1&-1 \\
# \end{bmatrix},
# b_3 =
# \begin{bmatrix}
#    0 \\
#    0 \\
#    0
# \end{bmatrix}$$
# $$ h^3(x) =
# \begin{bmatrix}
#    1&-2&1 \\
#    1&2&-1 \\
#    -1&1&-1 \\
# \end{bmatrix}
# \begin{bmatrix}
#    2 \\
#    8 \\
#    -4
# \end{bmatrix}
# +
# \begin{bmatrix}
#    0 \\
#    0 \\
#    0
# \end{bmatrix} =
# \begin{bmatrix}
#    -18 \\
#    22 \\
#    10
# \end{bmatrix}$$

# %% [markdown]
# <span style="color:blue">**(d)**</span><br>
# $$ p(x) = softmax(\begin{bmatrix}
#    -18 \\
#    22 \\
#    10
# \end{bmatrix}^T) =
# \begin{bmatrix}
#    4.24832815e^{-18} & 9.99993856e^{-01} & 6.14417460e^{-06}
# \end{bmatrix} $$

# %% [markdown]
# <span style="color:blue">**(e)**</span><br>
# $$ l(x,y) = - \log{p_{y} (x)} = -\log(
# \begin{bmatrix}
#     0 \\
#     1 \\
#     0
# \end{bmatrix}
# \begin{bmatrix}
#    4.24832815e^{-18} & 9.99993856e^{-01} & 6.14417460e^{-06}
# \end{bmatrix}) = 6.144193477725374e^{-06} $$

# %% [markdown]
# <span style="color:blue">**(f)**</span>
# $$ LabelSmoothing = (1-0.1)*[0, 1, 0] + 0.1/10$$
# $$ l(x,y) = - \log{p_{y} (x)} = -\log(
# \begin{bmatrix}
#     0.01 \\
#     0.91 \\
#     0.01
# \end{bmatrix}
# \begin{bmatrix}
#    4.24832815e^{-18} & 9.99993856e^{-01} & 6.14417460e^{-06}
# \end{bmatrix}) = 0.2811866091675827 $$

# %%
#Form matrix representation using numpy
x = np.array([[1],[-1],[1]])
w_1 = np.array([
    [1,-1,1],
    [1,-1,-1],
    [2,-1,2],
    [-1,-2,1]
])
b_1 = np.array([[1],[0],[1],[0]])
w_2 = np.array([
    [1,-1,-1,2],
    [1,-1,1,-1],
    [-1,2,-1,2]
], dtype='float64')
b_2 = np.array([[1],[1],[0]])
w_3 = np.array(
    [[1,-2,1],
    [1,2,-1],
    [-1,1,-1]]
)
b_3 = np.zeros((3,1))

# %%
#a)
h1 = w_1.dot(x) + b_1
#b)
h2 = w_2.dot(h1) + b_2
#c)
h3 = w_3.dot(h2) + b_3
#d)
softmax = tf.nn.softmax(h3.reshape(-1))
print(softmax.numpy())
#e) 
loss = tf.keras.losses.CategoricalCrossentropy()(np.array([0,1,0]), softmax).numpy()
print(loss)
#f)
ls_y = (1-0.1)*np.array([0,1,0]) + 0.1/10
ls_loss = tf.keras.losses.CategoricalCrossentropy()(ls_y, softmax).numpy()
print(ls_loss)
# Out:
# [4.24832815e-18 9.99993856e-01 6.14417460e-06]
# 6.144193477725374e-06
# 0.2811866091675827

# %% [markdown]
# ####  <span style="color:red">**Question 1.3**</span> **Assume that we are constructing a multilayered feed-forward neural network for a classification problem with three classes where the model parameters will be generated randomly using your student ID. The architecture of this network is ($3 (Input)\rightarrow4(LeakyReLU)\rightarrow 3(Output)$) as shown in the following figure. Note that the LeakyReLU has the same formula as the one in Q1.1.**
#
#
# <img src="Figures/Q3_P1.png" width="500" align="center"/>
#
# We feed a feature vector $x=\left[\begin{array}{ccc}
# 1 & -1 & 1.5\end{array}\right]^{T}$ with ground-truth label $y=3$ to the above network.

# %% [markdown]
# **You need to show both formulas, numerical results, and your numpy code for your computation for earning full marks.**

# %%
#Code to generate random matrices and biases for W1, b1, W2, b2
import numpy as np
student_id = 31259030           #insert your student id here for example 1234    
np.random.seed(student_id)
W1 = np.random.rand(4,3)
b1 = np.random.rand(4,1)
W2 = np.random.rand(3,4)
b2 = np.random.rand(3,1)
one_y = np.array([0,0,1])

# %% [markdown]
# **Forward propagation**
#
# <span style="color:red">**(a)**</span>  What is the value of $\bar{h}^{1}(x)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>

# %% [markdown]
# *Show your fomula*
# $$ \bar{h}^1(x) = W_1 \cdot{x} + b_1 $$

# %%
# Show your code
x = np.array([[1],[-1],[1.5]])
h1_bar = W1.dot(x) + b1
print(h1_bar)
# Out:
# [[2.52402332]
#  [0.83448646]
#  [0.94158794]
#  [1.61126381]]

# %% [markdown]
# <span style="color:red">**(b)**</span>  What is the value of $h^{1}(x)$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>

# %% [markdown]
# *Show your fomular*
# $$ h^1(x) = LeakyReLu(\bar{h}^1) $$

# %%
#Show your code
#LeakyReLU function
def leakyrelu(x):
    return np.where(x<0, 0.01*x, x)

h1 = leakyrelu(h1_bar)
print(h1)
# Out:
# [[2.52402332]
#  [0.83448646]
#  [0.94158794]
#  [1.61126381]]

# %% [markdown]
# <span style="color:red">**(c)**</span>  What is the predicted value $\hat{y}$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>

# %% [markdown]
# *Show your fomula*
# $$ h^2 = W_2 \cdot{h^1} + b_2$$
# $$ p(x) = softmax(h^2)$$
# $$ \hat{y} = max(p(x)) $$

# %%
#Show your code
h2 = W2.dot(h1) + b2
p = tf.nn.softmax(h2.flatten())
print('Predicted value is {}'.format(p.numpy().argmax()+1))
# Out:
# Predicted value is 3

# %% [markdown]
# <span style="color:red">**(d)**</span>  Suppose that we use the cross-entropy (CE) loss. What is the value of the CE loss $l$?
# <div style="text-align: right"><span style="color:red">[1 point]</span></div>

# %% [markdown]
# *Show your fomula*
# $$ l(x,y) = - \log{p_{y} (x)} = -\log(
# \begin{bmatrix}
#     0 \\
#     0 \\
#     1
# \end{bmatrix}
# \begin{bmatrix}
#    0.09594999 & 0.27656929 & 0.62748072
# \end{bmatrix}) = 0.4660423332521088 $$

# %%
#Show your code
loss = tf.keras.losses.CategoricalCrossentropy()(one_y, p).numpy()
print('Value of CE loss, l = {}'.format(loss))
# Out:
# Value of CE loss, l = 0.4660423332521088

# %% [markdown]
# **Backward propagation**
#
# <span style="color:red">**(e)**</span> What are the derivatives $\frac{\partial l}{\partial h^{2}},\frac{\partial l}{\partial W^{2}}$, and $\frac{\partial l}{\partial b^{2}}$?
# <div style="text-align: right"><span style="color:red">[6 points]</span></div>

# %% [markdown]
# *Show your fomula*
# $$l = -log(\frac{\exp(h^{2}_y(x))}{\sum_{m=1}^{M}\exp(h^{2}_m(x))})$$
# $$h^2 = W\cdot(h^2) +b$$
# $$g^2 = \frac{\partial l}{\partial h^{2}} = softmax(h^2) - 1_y$$
#
# $$\frac{\partial l}{\partial W^{2}} =  \frac{\partial l}{\partial h^{2}} \cdot{\frac{\partial h^2}{\partial W^{2}}} = (g^2)^T(h^1)^T$$
# $$\frac{\partial l}{\partial b^{2}} =  \frac{\partial l}{\partial h^{2}} \cdot{\frac{\partial h^2}{\partial b^{2}}} = g^2$$

# %%
#Show your code
g2 = (tf.nn.softmax(h2.flatten())-one_y).numpy()
l_W2 = g2.reshape(3,1).dot(h1.transpose())
l_b2 = g2
print(g2)
print(l_W2)
print(l_b2)
# Out:
# [ 0.09594999  0.27656929 -0.37251928]
# [[ 0.24218001  0.08006897  0.09034535  0.15460074]
#  [ 0.69806734  0.23079333  0.26041431  0.44562609]
#  [-0.94024735 -0.31086229 -0.35075966 -0.60022683]]
# [ 0.09594999  0.27656929 -0.37251928]

# %% [markdown]
# <span style="color:red">**(f)**</span> What are the derivatives $\frac{\partial l}{\partial h^{1}}, \frac{\partial l}{\partial \bar{h}^{1}},\frac{\partial l}{\partial W^{1}}$, and $\frac{\partial l}{\partial b^{1}}$?
# <div style="text-align: right"><span style="color:red">[6 points]</span></div>

# %% [markdown]
# *Show your formula*
#
# $$g^1 = \frac{\partial l}{\partial h^{1}} = \frac{\partial l}{\partial h^{2}} \cdot{\frac{\partial h^2}{\partial h^{1}}} = g^2W^2,$$
#
# $$ h^1 = \sigma{(\bar{h^1})}$$
# $$\frac{\partial h^1}{\partial \bar{h^{1}}} = diag(\sigma{'(\bar{h^1})})$$
# $$\bar{g}^1 = \frac{\partial l}{\partial \bar{h}^{1}} = \frac{\partial l}{\partial h^{1}} \cdot{\frac{\partial h^1}{\partial \bar{h}^1}} = g^1diag(\sigma{'(\bar{h}^1)}),$$
#
# $$\frac{\partial l}{\partial W^{1}} = \frac{\partial l}{\partial \bar{h}^1} \cdot{\frac{\partial \bar{h}^1}{\partial W^{1}}} = (\bar{g}^1)^T(h^0)^T,$$
#
# $$\frac{\partial l}{\partial b^{1}} = \frac{\partial l}{\partial \bar{h}^1} \cdot{\frac{\partial \bar{h}^1}{\partial b^{1}}} = \bar{g}^1 $$

# %%
#Show your code
g1 = g2.dot(W2)
g_bar_one = g1.dot(np.diag((h1*(1-h1))[:,0]))
l_W1 = g_bar_one.reshape(-1,1).dot(x.transpose())
l_b1 = g_bar_one
print(g1)
print(g_bar_one)
print(l_W1)
print(l_b1)
# Out:
# [-0.04735902  0.08134511 -0.07632661 -0.04144328]
# [ 0.18217452  0.01123529 -0.00419797  0.04081779]
# [[ 0.18217452 -0.18217452  0.27326179]
#  [ 0.01123529 -0.01123529  0.01685293]
#  [-0.00419797  0.00419797 -0.00629696]
#  [ 0.04081779 -0.04081779  0.06122669]]
# [ 0.18217452  0.01123529 -0.00419797  0.04081779]

# %% [markdown]
# **SGD update**
#
# <span style="color:red">**(g)**</span> Assume that we use SGD with learning rate $\eta=0.01$ to update the model parameters. What are the values of $W^2, b^2$ and $W^1, b^1$ after updating?
# <div style="text-align: right"><span style="color:red">[5 points]</span></div>

# %% [markdown]
# *Show your formula*
# $$ W^2 = W^2 - \eta \frac{\partial l}{\partial W^{2}}$$
# $$ b^2 = b^2 - \eta \frac{\partial l}{\partial b^{2}}$$
# $$ W^1 = W^1 - \eta \frac{\partial l}{\partial W^{1}}$$
# $$ b^1 = b^1 - \eta \frac{\partial l}{\partial b^{1}}$$

# %%
#Show your code
n = 0.01
W2 = W2 - n*l_W2
b2 = b2 - n*l_b2

W1 = W1 - n*l_W1
b1 = b1 - n*l_b1

print('Values after updating are \n W1 : {}, \nb1 : {}, \nW2 : {}, \nb2 : {}'.format(W1, b1, W2, b2))
# Out:
# Values after updating are
#  W1 : [[0.97921254 0.30741076 0.82326192]
#  [0.61610312 0.7169532  0.19524959]
#  [0.31775283 0.6020372  0.77744501]
#  [0.84162713 0.56253692 0.83735274]],
# b1 : [[0.60776448 0.60947387 0.60962821 0.60917805]
#  [0.6401629  0.64187229 0.64202662 0.64157647]
#  [0.05806147 0.05977086 0.0599252  0.05947504]
#  [0.07258798 0.07429737 0.07445171 0.07400155]],
# W2 : [[0.57311813 0.57587201 0.36858812 0.35497758]
#  [0.9352381  0.38336605 0.13889248 0.93035989]
#  [0.9843073  0.21961341 0.40862205 0.90311867]],
# b2 : [[0.65837849 0.6565723  0.66306318]
#  [0.23378808 0.23198188 0.23847277]
#  [0.92423354 0.92242734 0.92891823]]

# %% [markdown]
# ## <span style="color:#0b486b">Part 2: Deep Neural Networks (DNN) </span>
# <div style="text-align: right"><span style="color:red; font-weight:bold">[Total marks for this part: 30 points]<span></div>
#
# The first part of this assignment is for you to demonstrate your basis knowledge in deep learning that you have acquired from the lectures and tutorials materials. Most of the contents in this assignment are drawn from **the tutorials covered from weeks 1 to 4**. Going through these materials before attempting this assignment is highly recommended.

# %% [markdown]
# In the first part of this assignment, you are going to work with the **FashionMNIST** dataset for *image recognition task*. It has the exact same format as MNIST (70,000 grayscale images of 28 × 28 pixels each with 10 classes), but the images represent fashion items rather than handwritten digits, so each class is more diverse, and the problem is significantly more challenging than MNIST.

# %% [markdown]
# ####  <span style="color:red">**Question 2.1**</span>. Load the Fashion MNIST using Keras datasets
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>
#
# We first use keras incoporated in TensorFlow 2.x for loading the training and testing sets.

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
tf.random.set_seed(1234)
keras.backend.clear_session()

# %% [markdown]
# We first use keras datasets in TF 2.x to load Fashion MNIST dataset.

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full_img, y_train_full), (X_test_img, y_test) = fashion_mnist.load_data() #Insert your code here

# %% [markdown]
# The shape of X_train_full_img is $(60000, 28, 28 )$ and that of X_test_img is $(10000, 28, 28)$. We next convert them to matrices of vectors and store in X_train_full and X_test.

# %%
num_train = X_train_full_img.shape[0]
num_test = X_test_img.shape[0]
X_train_full =  np.reshape(X_train_full_img, (num_train, 784)) #Insert your code here
X_test =  np.reshape(X_test_img, (num_test, 784))  #Insert your code here
print(X_train_full.shape, y_train_full.shape)
print(X_test.shape, y_test.shape)
# Out:
# (60000, 784) (60000,)
# (10000, 784) (10000,)

# %% [markdown]
# ####  <span style="color:red">**Question 2.2**</span>. Preprocess the dataset and split into training, validation, and testing datasets
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>
#
# You need to write the code to address the following requirements:
# - Print out the dimensions of X_train_full and X_test
# - Use $10 \%$ of X_train_full for validation and the rest of X_train_full for training. This splits X_train_full and y_train_full into X_train, y_train ($90 \%$) and X_valid, y_valid ($10 \%$).
# - Finally, scale the pixels of X_train, X_valid, and X_test to $[0,1]$) (i.e., $X = X/255.0$).
#
# You have now the separate training, validation, and testing sets for training your model.

# %%
import math
N = X_train_full.shape[0]
i = math.floor(0.9*N)

X_train, y_train = X_train_full[:i, :], y_train_full[:i]#Insert your code here
X_valid, y_valid = X_train_full[i:, : ], y_train_full[i:]#Insert your code here
X_train, X_valid, X_test = (X_train/255.0), (X_valid/255.0), (X_test/255.0) #Insert your code here
print(X_train_full.shape)
print(X_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ####  <span style="color:red">**Question 2.3**</span>. Visualize some images in the training set with labels
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>
#
# You are required to write the code to show **random** $36$ images in X_train_full_img (which is an array of images) with labels as in the following figure. Note that the class names of Fashion MNIST are as follows
# - "1:T-shirt/top", "2:Trouser", "3:Pullover", "4:Dress", "5:Coat", "6:Sandal", "7:Shirt", "8:Sneaker", "9:Bag", "10:Ankle boot"
#
# <img src="Figures/Fashion_MNIST.png" width="450" align="center"/>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# YOU ARE REQUIRED TO INSERT YOUR CODES IN THIS CELL
def show_images(x_train, y_train, labels, num2display):
    fig = plt.figure(figsize=(36,36))
    for i in range(num2display):
        plt.subplot(6,6,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        img_ind = np.random.randint(0, x_train.shape[0])
        plt.imshow(x_train[img_ind], cmap="gray_r")
        plt.xlabel(labels[y_train[img_ind]], fontsize="24")

labels = ["1:T-shirt/top", "2:Trouser", "3:Pullover", "4:Dress", "5:Coat", "6:Sandal", "7:Shirt", "8:Sneaker", "9:Bag", "10:Ankle boot"]
show_images(X_train_full_img, y_train_full, labels, 36)

# %% [markdown]
# ####  <span style="color:red">**Question 2.4**</span>. Write code for the feed-forward neural net using TF 2.x
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>

# %% [markdown]
# We now develop a feed-forward neural network with the architecture $784 \rightarrow 20(ReLU) \rightarrow 40(ReLU) \rightarrow 10(softmax)$. You can choose your own way to implement your network and an optimizer of interest. You should train model in $20$ epochs and evaluate the trained model on the test set.

# %%
#Insert your code here and you can add more cells if necessary
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow import keras

# %%
dnn_model = Sequential()
dnn_model.add(Dense(units=20, input_shape=(784,), activation='relu'))
dnn_model.add(Dense(units=40, activation='relu'))
dnn_model.add(Dense(units=10, activation='softmax'))

dnn_model.build()
dnn_model.summary()

dnn_model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                15700
#
#  dense_1 (Dense)             (None, 40)                840
#
#  dense_2 (Dense)             (None, 10)                410
#
# =================================================================
# Total params: 16,950
# Trainable params: 16,950
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = dnn_model.fit(x=X_train, y=y_train, batch_size=32,
                            epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 1688/1688 [==============================] - 10s 5ms/step - loss: 1.9150 - accuracy: 0.3599 - val_loss: 1.5073 - val_accuracy: 0.5987
# Epoch 2/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.2737 - accuracy: 0.6251 - val_loss: 1.0775 - val_accuracy: 0.6582
# Epoch 3/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.9917 - accuracy: 0.6664 - val_loss: 0.8924 - val_accuracy: 0.6982
# Epoch 4/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.8546 - accuracy: 0.7059 - val_loss: 0.7918 - val_accuracy: 0.7335
# Epoch 5/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.7736 - accuracy: 0.7343 - val_loss: 0.7300 - val_accuracy: 0.7520
# Epoch 6/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.7195 - accuracy: 0.7517 - val_loss: 0.6848 - val_accuracy: 0.7620
# Epoch 7/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.6800 - accuracy: 0.7642 - val_loss: 0.6527 - val_accuracy: 0.7720
# Epoch 8/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6489 - accuracy: 0.7745 - val_loss: 0.6275 - val_accuracy: 0.7825
# Epoch 9/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6241 - accuracy: 0.7834 - val_loss: 0.6057 - val_accuracy: 0.7882
# Epoch 10/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6043 - accuracy: 0.7910 - val_loss: 0.5892 - val_accuracy: 0.7962
# Epoch 11/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.5875 - accuracy: 0.7969 - val_loss: 0.5786 - val_accuracy: 0.7955
# Epoch 12/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5731 - accuracy: 0.8034 - val_loss: 0.5598 - val_accuracy: 0.8047
# Epoch 13/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5605 - accuracy: 0.8072 - val_loss: 0.5486 - val_accuracy: 0.8083
# Epoch 14/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.5494 - accuracy: 0.8112 - val_loss: 0.5405 - val_accuracy: 0.8097
# Epoch 15/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5392 - accuracy: 0.8150 - val_loss: 0.5335 - val_accuracy: 0.8162
# Epoch 16/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.5303 - accuracy: 0.8191 - val_loss: 0.5238 - val_accuracy: 0.8165
# Epoch 17/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.5222 - accuracy: 0.8213 - val_loss: 0.5168 - val_accuracy: 0.8205
# Epoch 18/20
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.5148 - accuracy: 0.8239 - val_loss: 0.5093 - val_accuracy: 0.8217
# Epoch 19/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5080 - accuracy: 0.8257 - val_loss: 0.5044 - val_accuracy: 0.8237
# Epoch 20/20
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.5020 - accuracy: 0.8287 - val_loss: 0.4991 - val_accuracy: 0.8262

# %%
#Evaluate training model
dnn_model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5251 - accuracy: 0.8153
# [0.5251021385192871, 0.8152999877929688]

# %%
import matplotlib.pyplot as plt

def plot_hist (hist_obj):
    his = hist_obj.history 
    fig = plt.figure(figsize=(8, 5))
    ax = fig.add_subplot(111)
    ln1 = ax.plot(his['loss'], 'b--',label='loss')
    ln2 = ax.plot(his['val_loss'], 'b-',label='val_loss')
    ax.set_ylabel('loss', color='blue')
    ax.tick_params(axis='y', colors="blue")

    ax2 = ax.twinx()
    ln3 = ax2.plot(his['accuracy'], 'r--',label='accuracy')
    ln4 = ax2.plot(his['val_accuracy'], 'r-',label='val_accuracy')
    ax2.set_ylabel('accuracy', color='red')
    ax2.tick_params(axis='y', colors="red")


    lns = ln1 + ln2 + ln3 + ln4 
    labels = [l.get_label() for l in lns]
    ax.legend(lns, labels)
    plt.grid(True)
    plt.show()
plot_hist(history)

# %% [markdown]
# ####  <span style="color:red">**Question 2.5**</span>. Tuning hyper-parameters with grid search
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>
#
# Assume that you need to tune the number of neurons on the first and second hidden layers $n_1 \in \{20, 40\}$, $n_2 \in \{20, 40\}$  and the used activation function  $act \in \{sigmoid, tanh, relu\}$. The network has the architecture pattern $784 \rightarrow n_1 (act) \rightarrow n_2(act) \rightarrow 10(softmax)$ where $n_1, n_2$, and $act$ are in their grides. Write the code to tune the hyper-parameters $n_1, n_2$, and $act$. Note that you can freely choose the optimizer and learning rate of interest for this task.

# %%
#Insert your code here. You can add more cells if necessary
class DNN (keras.Model):
    def __init__(self, n_classes, n1, n2, act) -> None:
        super(DNN, self).__init__()
        self.n_classes = n_classes
        self.dense1 = keras.layers.Dense(units=n1, input_shape=(784,), activation=act)
        self.dense2 = keras.layers.Dense(units=n2, activation=act)
        self.dense3 = keras.layers.Dense(units=self.n_classes, activation=act)

    def call(self,X):
        h = self.dense1(X)
        h = self.dense2(h)
        h = self.dense3(h)
        return h

# %%
lst_n1 = [20,40]
lst_n2 = [20,40]
lst_act = ['sigmoid', 'tanh', 'relu']
best_acc = - np.inf 
best_history = None

for n1 in lst_n1:
    for n2 in lst_n2:
        for act in lst_act:
            dnn = DNN(10, n1, n2, act)
            dnn.compile(optimizer='SGD', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
            print("Training with n1 = {}, n2 = {}, activation = {}".format(n1, n2, act))
            history = dnn.fit(X_train, y_train, batch_size=32, epochs=10)
            valid_loss, valid_acc = dnn.evaluate(X_valid, y_valid)
            print('\tvalid acc = {}, valid loss = {}'.format(valid_acc, valid_loss))
            if(valid_acc > best_acc):
                best_n1 = n1
                best_n2 = n2
                best_act = act
                best_acc = valid_acc
                best_model = dnn
                best_history = history
    
print('\nThe best model is with n1 = {}, n2 = {}, act = {}'.format(best_n1, best_n2, best_act))
#save best model
# best_model.save('best_model', save_format='tf')
# Out:
# Training with n1 = 20, n2 = 20, activation = sigmoid
# Epoch 1/10
# 1688/1688 [==============================] - 8s 4ms/step - loss: 2.2115 - accuracy: 0.3215
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 1.8800 - accuracy: 0.4370
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.5084 - accuracy: 0.5398
# Epoch 4/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 1.2613 - accuracy: 0.6065
# Epoch 5/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 1.1026 - accuracy: 0.6516
# Epoch 6/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.9862 - accuracy: 0.6886
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.8974 - accuracy: 0.7129
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.8289 - accuracy: 0.7278
# Epoch 9/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.7754 - accuracy: 0.7391
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7329 - accuracy: 0.7466
# 188/188 [==============================] - 1s 4ms/step - loss: 0.7082 - accuracy: 0.7562
# 	valid acc = 0.7561666369438171, valid loss = 0.7081777453422546
# Training with n1 = 20, n2 = 20, activation = tanh
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3909 - accuracy: 0.1600
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3024 - accuracy: 0.1617
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 8/10
# 1688/1688 [==============================] - 12s 7ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.3024 - accuracy: 0.1618
# 188/188 [==============================] - 1s 4ms/step - loss: 2.3018 - accuracy: 0.1617
# 	valid acc = 0.1616666615009308, valid loss = 2.3018150329589844
# Training with n1 = 20, n2 = 20, activation = relu
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 6.9364 - accuracy: 0.1820
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6593 - accuracy: 0.1008
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6592 - accuracy: 0.1008
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6593 - accuracy: 0.1008
# Epoch 5/10
# 1688/1688 [==============================] - 8s 4ms/step - loss: 9.6593 - accuracy: 0.1008
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6593 - accuracy: 0.1008
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6593 - accuracy: 0.1008
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6592 - accuracy: 0.1008
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6592 - accuracy: 0.1008
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 9.6593 - accuracy: 0.1008
# 188/188 [==============================] - 1s 4ms/step - loss: 9.7518 - accuracy: 0.0925
# 	valid acc = 0.0925000011920929, valid loss = 9.751762390136719
# Training with n1 = 20, n2 = 40, activation = sigmoid
# Epoch 1/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.2116 - accuracy: 0.3669
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.8118 - accuracy: 0.4706
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.3866 - accuracy: 0.5557
# Epoch 4/10
# 1688/1688 [==============================] - 9s 6ms/step - loss: 1.1830 - accuracy: 0.5978
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.0608 - accuracy: 0.6252
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.9718 - accuracy: 0.6571
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.9019 - accuracy: 0.6802
# Epoch 8/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 0.8434 - accuracy: 0.6972
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7936 - accuracy: 0.7112
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7526 - accuracy: 0.7231
# 188/188 [==============================] - 1s 4ms/step - loss: 0.7288 - accuracy: 0.7488
# 	valid acc = 0.7488333582878113, valid loss = 0.7288161516189575
# Training with n1 = 20, n2 = 40, activation = tanh
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 5.7693 - accuracy: 0.1261
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 3.7575 - accuracy: 0.2336
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 10.9657 - accuracy: 0.0999
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 10.9634 - accuracy: 0.0996
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 11.0519 - accuracy: 0.0994
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 11.0193 - accuracy: 0.0994
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 9.6262 - accuracy: 0.0994
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 8.5170 - accuracy: 0.1311
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 6.0704 - accuracy: 0.1884
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 6.1411 - accuracy: 0.1747
# 188/188 [==============================] - 1s 4ms/step - loss: 6.4445 - accuracy: 0.1008
# 	valid acc = 0.10083333402872086, valid loss = 6.444468021392822
# Training with n1 = 20, n2 = 40, activation = relu
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 8.7206 - accuracy: 0.0995
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 9.6748 - accuracy: 0.0994
# 188/188 [==============================] - 1s 4ms/step - loss: 9.6121 - accuracy: 0.1050
# 	valid acc = 0.10499999672174454, valid loss = 9.612069129943848
# Training with n1 = 40, n2 = 20, activation = sigmoid
# Epoch 1/10
# 1688/1688 [==============================] - 8s 4ms/step - loss: 2.1378 - accuracy: 0.4029
# Epoch 2/10
# 1688/1688 [==============================] - 7s 4ms/step - loss: 1.6705 - accuracy: 0.5563
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.3554 - accuracy: 0.5952
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.1479 - accuracy: 0.6369
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.0025 - accuracy: 0.6727
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.9014 - accuracy: 0.6955
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.8305 - accuracy: 0.7131
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7780 - accuracy: 0.7314
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7362 - accuracy: 0.7451
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7009 - accuracy: 0.7576
# 188/188 [==============================] - 1s 5ms/step - loss: 0.6770 - accuracy: 0.7695
# 	valid acc = 0.7695000171661377, valid loss = 0.6770406365394592
# Training with n1 = 40, n2 = 20, activation = tanh
# Epoch 1/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.2910 - accuracy: 0.1476
# Epoch 2/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 11.5918 - accuracy: 0.0984
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3828 - accuracy: 0.0999
# 188/188 [==============================] - 1s 4ms/step - loss: 12.3678 - accuracy: 0.1008
# 	valid acc = 0.10083333402872086, valid loss = 12.367844581604004
# Training with n1 = 40, n2 = 20, activation = relu
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 4.0658 - accuracy: 0.2394
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.9872 - accuracy: 0.2647
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 4.0765 - accuracy: 0.2343
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 4.9035 - accuracy: 0.2006
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 4.8945 - accuracy: 0.2007
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 4.8543 - accuracy: 0.2008
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 4.3628 - accuracy: 0.1841
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 6.3962 - accuracy: 0.1110
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 3.4946 - accuracy: 0.1830
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 3.6543 - accuracy: 0.2008
# 188/188 [==============================] - 1s 4ms/step - loss: 3.6539 - accuracy: 0.1898
# 	valid acc = 0.18983332812786102, valid loss = 3.653886318206787
# Training with n1 = 40, n2 = 40, activation = sigmoid
# Epoch 1/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.1379 - accuracy: 0.3748
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.6034 - accuracy: 0.5092
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.2509 - accuracy: 0.5951
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.0594 - accuracy: 0.6486
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.9326 - accuracy: 0.6876
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.8416 - accuracy: 0.7131
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 0.7749 - accuracy: 0.7318
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.7243 - accuracy: 0.7452
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6846 - accuracy: 0.7559
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 0.6528 - accuracy: 0.7654
# 188/188 [==============================] - 1s 4ms/step - loss: 0.6339 - accuracy: 0.7765
# 	valid acc = 0.7764999866485596, valid loss = 0.6339267492294312
# Training with n1 = 40, n2 = 40, activation = tanh
# Epoch 1/10
# 1688/1688 [==============================] - 10s 6ms/step - loss: 2.5084 - accuracy: 0.1610
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 4.6874 - accuracy: 0.2178
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 4.9564 - accuracy: 0.1387
# Epoch 4/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.8908 - accuracy: 0.1459
# Epoch 5/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 3.3243 - accuracy: 0.1137
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 3.2956 - accuracy: 0.1758
# Epoch 7/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 3.5145 - accuracy: 0.1584
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 5.8179 - accuracy: 0.1009
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 6.5829 - accuracy: 0.1000
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 7.2501 - accuracy: 0.1000
# 188/188 [==============================] - 1s 4ms/step - loss: 8.1831 - accuracy: 0.1003
# 	valid acc = 0.1003333330154419, valid loss = 8.183124542236328
# Training with n1 = 40, n2 = 40, activation = relu
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3728 - accuracy: 0.1006
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 6/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# Epoch 10/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 12.3738 - accuracy: 0.1006
# 188/188 [==============================] - 1s 4ms/step - loss: 12.4484 - accuracy: 0.0942
# 	valid acc = 0.09416666626930237, valid loss = 12.44843578338623
#
# The best model is with n1 = 40, n2 = 40, act = sigmoid

# %% [markdown]
# ####  <span style="color:red">**Question 2.6**</span>. Experimenting with **the label smoothing** technique
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>
#
# Implement the label smoothing technique (i.e., [link for main paper](https://papers.nips.cc/paper/2019/file/f1748d6b0fd9d439f71450117eba2725-Paper.pdf) from Goeff Hinton) by yourself. Note that you cannot use the built-in label-smoothing loss function in TF2.x. Try the label smoothing technique with $\alpha =0.1, 0.15, 0.2$ and report the performances. You need to examine the label smoothing technique with the best architecture obtained in **Question 2.5**.

# %%
#Insert your code here. You can add more cells if necessary
#convert label to one hot vector
# y_test_hot = tf.one_hot(y_test, depth=10)
y_train_hot = tf.one_hot(y_train, depth=10)
y_valid_hot = tf.one_hot(y_valid, depth=10)
alpha_lst = [0.1, 0.15, 0.2]

best_acc = - np.inf
best_history = None
# y_test_ls = tf.map_fn(fn=lambda x: ((1-alpha)*x)+(alpha*10), elems=y_valid_hot)

#load saved model from 2.5
for alpha in alpha_lst:
    y_train_ls = tf.map_fn(fn=lambda x: ((1-alpha)*x)+(alpha/10), elems=y_train_hot)
    y_valid_ls = tf.map_fn(fn=lambda x: ((1-alpha)*x)+(alpha/10), elems=y_valid_hot)

    dnn = DNN(10, 40, 40, 'sigmoid')
    dnn.build(input_shape=())
    # best_model = keras.models.load_model('best_model')
    dnn.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
    history = dnn.fit(X_train, y_train_ls, batch_size=32, epochs=10)
    
    valid_loss, valid_acc = dnn.evaluate(X_valid, y_valid_ls)
    print('\tvalid acc = {}, valid loss = {}'.format(valid_acc, valid_loss))
    if valid_acc > best_acc:
        best_acc = valid_acc
        best_history = history
        best_alpha = alpha
        
print('\nThe best model yields an accuracy of {} with alpha = {}'.format(best_acc, best_alpha))
# Out:
# Epoch 1/10
# 1688/1688 [==============================] - 10s 5ms/step - loss: 2.1843 - accuracy: 0.3402
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.8170 - accuracy: 0.5505
# Epoch 3/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.5439 - accuracy: 0.6181
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.3763 - accuracy: 0.6588
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.2658 - accuracy: 0.6860
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.1907 - accuracy: 0.7079
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.1396 - accuracy: 0.7266
# Epoch 8/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.1026 - accuracy: 0.7416
# Epoch 9/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.0738 - accuracy: 0.7542
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.0505 - accuracy: 0.7644
# 188/188 [==============================] - 1s 5ms/step - loss: 1.0357 - accuracy: 0.7733
# 	valid acc = 0.7733333110809326, valid loss = 1.0357489585876465
# Epoch 1/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 2.2160 - accuracy: 0.3889
# Epoch 2/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.9032 - accuracy: 0.5249
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.6391 - accuracy: 0.5777
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.4976 - accuracy: 0.6186
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.4130 - accuracy: 0.6582
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.3520 - accuracy: 0.6906
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.3061 - accuracy: 0.7098
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.2716 - accuracy: 0.7236
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.2445 - accuracy: 0.7338
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.2223 - accuracy: 0.7434
# 188/188 [==============================] - 1s 5ms/step - loss: 1.2079 - accuracy: 0.7525
# 	valid acc = 0.7524999976158142, valid loss = 1.2079092264175415
# Epoch 1/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 2.2335 - accuracy: 0.3519
# Epoch 2/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.9692 - accuracy: 0.4986
# Epoch 3/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.7332 - accuracy: 0.5647
# Epoch 4/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.6223 - accuracy: 0.5979
# Epoch 5/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.5586 - accuracy: 0.6231
# Epoch 6/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.5118 - accuracy: 0.6536
# Epoch 7/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.4725 - accuracy: 0.6829
# Epoch 8/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.4382 - accuracy: 0.7048
# Epoch 9/10
# 1688/1688 [==============================] - 9s 5ms/step - loss: 1.4084 - accuracy: 0.7195
# Epoch 10/10
# 1688/1688 [==============================] - 8s 5ms/step - loss: 1.3831 - accuracy: 0.7313
# 188/188 [==============================] - 1s 4ms/step - loss: 1.3663 - accuracy: 0.7465
# 	valid acc = 0.7465000152587891, valid loss = 1.3662577867507935
#
# The best model yields an accuracy of 0.7733333110809326 with alpha = 0.1

# %% [markdown]
# ## <span style="color:#0b486b">Part 3: Convolutional Neural Networks and Image Classification</span>
#
# **<div style="text-align: right"><span style="color:red">[Total marks for this part: 40 points]</span></div>**

# %% [markdown]
# **This part of the asssignment is designed to assess your knowledge and coding skill with Tensorflow as well as hands-on experience with training Convolutional Neural Network (CNN).**

# %% [markdown]
# **The dataset we use for this part is a small animal dataset consisting of $5,000$ images of cats, dogs, fishes, lions, chickens, elephants, butterflies, cows, spiders, and horses, each of which has 500 images. You can download the dataset at [download here](https://drive.google.com/file/d/1bEwEx72lLrjY_Idj_FgV22atIdjtCV66/view?usp=sharing) and then decompress to the folder `datasets\Animals` in your assignment folder.**
#
# **Your task is to build a CNN model using *TF 2.x* to classify these animals. You're provided with the module <span style="color:red">models.py</span>, which you can find in the assignment folder, with some of the following classes:**

# %% [markdown]
# 1. `AnimalsDatasetManager`: Support with loading and spliting the dataset into the train-val-test sets. It also supports generating next batches for training. `AnimalsDatasetManager` will be passed to CNN model for training and testing.
# 2. `DefaultModel`: A base class for the CNN model.
# 3. `YourModel`: The class you'll need to implement for building your CNN model. It inherits some useful attributes and functions from the base class `DefaultModel`

# %% [markdown]
# Firstly, we need to run the following cells to load and preprocess the Animal dataset.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Install the package `imutils` if you have not installed yet

# %%
! pip install imutils
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting imutils
#   Using cached imutils-0.5.4-py3-none-any.whl
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
import os
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline
import models
from models import SimplePreprocessor, AnimalsDatasetManager, DefaultModel

# %%
def create_label_folder_dict(adir):
    sub_folders= [folder for folder in os.listdir(adir)
                  if os.path.isdir(os.path.join(adir, folder))]
    label_folder_dict= dict()
    for folder in sub_folders:
        item= {folder: os.path.abspath(os.path.join(adir, folder))}
        label_folder_dict.update(item)
    return label_folder_dict

# %%
label_folder_dict= create_label_folder_dict("./datasets/Animals")

# %% [markdown]
# The below code helps to create a data manager that contains all relevant methods used to manage and process the experimental data.

# %%
sp = SimplePreprocessor(width=32, height=32)
data_manager = AnimalsDatasetManager([sp])
data_manager.load(label_folder_dict, verbose=100)
data_manager.process_data_label()
data_manager.train_valid_test_split()
# Out:
# butterfiles 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# cats 501
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# chickens 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# cows 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# dogs 501
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# elephants 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# fishes 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# horses 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# lions 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500
# spiders 500
# Processed 100/500
# Processed 200/500
# Processed 300/500
# Processed 400/500
# Processed 500/500

# %% [markdown]
# Note that the object `data_manager` has the attributes relating to *the training, validation, and testing sets* as shown belows. You can use them in training your developped models in the sequel.

# %%
print(data_manager.X_train.shape, data_manager.y_train.shape)
print(data_manager.X_valid.shape, data_manager.y_valid.shape)
print(data_manager.X_test.shape, data_manager.y_test.shape)
print(data_manager.classes)
# Out:
# (4000, 32, 32, 3) (4000,)
# (500, 32, 32, 3) (500,)
# (500, 32, 32, 3) (500,)
# ['butterfiles' 'cats' 'chickens' 'cows' 'dogs' 'elephants' 'fishes'
#  'horses' 'lions' 'spiders']

# %% [markdown]
# We now run the **default model** built in the **models.py** file which serves as a basic baseline to start the investigation. Follow the following steps to realize how to run a model and know the built-in methods associated to a model developped in the DefaultModel class.

# %% [markdown]
# We first initialize a default model from the DefaultModel class. Basically, we can define the relevant parameters of training a model including `num_classes`, `optimizer`, `learning_rate`, `batch_size`, and `num_epochs`.

# %%
network1 = DefaultModel(name='network1',
                       num_classes=len(data_manager.classes),
                       optimizer='sgd',
                       batch_size= 128,
                       num_epochs = 20,
                       learning_rate=0.5)

# %% [markdown]
# The method `build_cnn()` assists us in building your convolutional neural network. You can view the code (in the **models.py** file) of the model behind a default model to realize how simple it is. Additionally, the method `summary()` shows the architecture of a model.

# %%
network1.build_cnn()
network1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  average_pooling2d (AverageP  (None, 16, 16, 32)       0
#  ooling2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  average_pooling2d_1 (Averag  (None, 8, 8, 64)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 10)                40970
#
# =================================================================
# Total params: 106,538
# Trainable params: 106,538
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# To train a model regarding to the datasets stored in `data_manager`, you can invoke the method `fit()` for which you can specify the batch size and number of epochs for your training.

# %%
network1.fit(data_manager, batch_size = 64, num_epochs = 20)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 7s 19ms/step - loss: 2.2887 - accuracy: 0.1283 - val_loss: 2.3027 - val_accuracy: 0.1040
# Epoch 2/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3013 - accuracy: 0.0995 - val_loss: 2.3051 - val_accuracy: 0.0780
# Epoch 3/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3032 - accuracy: 0.0980 - val_loss: 2.2498 - val_accuracy: 0.1820
# Epoch 4/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3112 - accuracy: 0.1100 - val_loss: 2.3094 - val_accuracy: 0.0780
# Epoch 5/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3057 - accuracy: 0.0882 - val_loss: 2.3028 - val_accuracy: 0.1020
# Epoch 6/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3048 - accuracy: 0.0945 - val_loss: 2.3037 - val_accuracy: 0.1060
# Epoch 7/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3047 - accuracy: 0.0967 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 8/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3049 - accuracy: 0.0965 - val_loss: 2.3069 - val_accuracy: 0.1080
# Epoch 9/20
# 63/63 [==============================] - 1s 13ms/step - loss: 2.3042 - accuracy: 0.1047 - val_loss: 2.3035 - val_accuracy: 0.0960
# Epoch 10/20
# 63/63 [==============================] - 1s 13ms/step - loss: 2.3048 - accuracy: 0.0972 - val_loss: 2.3045 - val_accuracy: 0.1040
# Epoch 11/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3049 - accuracy: 0.0988 - val_loss: 2.3079 - val_accuracy: 0.0780
# Epoch 12/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3053 - accuracy: 0.0940 - val_loss: 2.3056 - val_accuracy: 0.0960
# Epoch 13/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3046 - accuracy: 0.0920 - val_loss: 2.3062 - val_accuracy: 0.1060
# Epoch 14/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3052 - accuracy: 0.0967 - val_loss: 2.3069 - val_accuracy: 0.1060
# Epoch 15/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3051 - accuracy: 0.0988 - val_loss: 2.3043 - val_accuracy: 0.1060
# Epoch 16/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3053 - accuracy: 0.0895 - val_loss: 2.3054 - val_accuracy: 0.0920
# Epoch 17/20
# 63/63 [==============================] - 1s 12ms/step - loss: 2.3053 - accuracy: 0.0938 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 18/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3049 - accuracy: 0.0887 - val_loss: 2.3036 - val_accuracy: 0.1080
# Epoch 19/20
# 63/63 [==============================] - 1s 10ms/step - loss: 2.3052 - accuracy: 0.0940 - val_loss: 2.3049 - val_accuracy: 0.0780
# Epoch 20/20
# 63/63 [==============================] - 1s 11ms/step - loss: 2.3052 - accuracy: 0.0940 - val_loss: 2.3054 - val_accuracy: 0.1060

# %% [markdown]
# Here you can compute the accuracy of your trained model with respect to a separate testing set.

# %%
network1.compute_accuracy(data_manager.X_test, data_manager.y_test)
# Out:
# 8/8 [==============================] - 0s 5ms/step - loss: 2.3044 - accuracy: 0.0840
# 0.08399999886751175

# %% [markdown]
# Below shows how you can inspect the training progress.

# %%
network1.plot_progress()

# %% [markdown]
# You can use the method `predict()` to predict labels for data examples in a test set.

# %%
network1.predict(data_manager.X_test[0:10])
# Out:
# 1/1 [==============================] - 0s 96ms/step
# array([3, 3, 3, 3, 3, 3, 3, 3, 3, 3], dtype=int64)

# %% [markdown]
# Finally, the method `plot_prediction()` visualizes the predictions for a test set in which several images are chosen to show the predictions.

# %%
network1.plot_prediction(data_manager.X_test, data_manager.y_test, data_manager.classes)
# Out:
# 16/16 [==============================] - 0s 4ms/step

# %% [markdown]
# <span style="color:red">**Question 3.1**</span> **After running the above cells to train the default model and observe the learning curve. Report your observation (i.e. did the model learn well? if not, what is the problem? What would you do to improve it?). Write your answer below.**
#
# <div style="text-align: right"> <span style="color:red">[4 points]</span> </div>

# %% [markdown]
# *#Your answer and observation here*<br>
# ### Answer :
# The model did not learn well at all as the training loss did not appear to decrease as epoch increases and instead appears to be stagnant, while training accuracy did not increase as its supposed to if the model learns well and instead is fluctuating all over the place. As the model failed to learn well, this in turn resulted in a bad performance for validation.

# %% [markdown]
# **For questions 3.2 to 3.9, you'll need to write your own model in a way that makes it easy for you to experiment with different architectures and parameters. The goal is to be able to pass the parameters to initialize a new instance of `YourModel` to build different network architectures with different parameters. Below are descriptions of some parameters for `YourModel`, which you can find in function `__init__()` for the class `DefaultModel`:**

# %% [markdown]
# 1. `num_blocks`: an integer specifying the number of blocks in our network. Each block has the pattern `[conv, batch norm, activation, conv, batch norm, activation, mean pool, dropout]`. All convolutional layers have filter size $(3, 3)$, strides $(1, 1)$ and 'SAME' padding, and all mean pool layers have strides $(2, 2)$ and 'SAME' padding. The network will consists of a few blocks before applying a linear layer to output the logits for the softmax layer.
#
# 2. `feature_maps`: the number of feature maps in the first block of the network. The number of feature_maps will double in each of the following block. To make it convenient for you, we already calculated the number of feature maps for each block for you in line $106$
# 3. `drop_rate`: the keep probability for dropout. Setting `drop_rate` to $0.0$ means not using dropout.
# 4. `batch_norm`: the batch normalization function is used or not. Setting `batch_norm` to `None` means not using batch normalization.
# 5. The `skip connection` is added to the output of the second `batch norm`. Additionally, your class has a boolean property (i.e., instance variable) named `use_skip`. If `use_skip=True`, the skip connectnion is enable. Otherwise, if `use_skip=False`, the skip connectnion is disable.
#
# Below is the architecture of one block:
#
# <img src="Figures/OneBlock.png" width="350" align="center"/>
#
# Below is the architecture of the entire deep net with `two blocks`:
#
# <img src="Figures/NetworkArchitecture.png" width="1200" align="center"/>

# %% [markdown]
# Here we assume that the first block has `feature_maps = feature_maps[0] = 32`. Note that the initial number of feature maps of the first block is declared in the instance variable `feature_maps` and is multiplied by $2$ in each follpwing block.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# %%
tf.random.set_seed(1234)

# %% [markdown]
# <span style="color:red">**Question 3.2**</span> **Write the code of the `YourModel` class here. Note that this class will inherit from the `DefaultModel` class. You'll only need to re-write the code for the `build_cnn` method in the `YourModel` class from the cell below. Note that the `YourModel` class   is inherited from the `DefaultModel` class.**
#
# <div style="text-align: right"> <span style="color:red">[4 points]</span> </div>

# %%
class YourModel(DefaultModel):
    def __init__(self,
                 name='network1',
                 width=32, height=32, depth=3,
                 num_blocks=2,
                 feature_maps=32,
                 num_classes=4, 
                 drop_rate=0.2,
                 batch_norm = None,
                 is_augmentation = False,
                 activation_func='relu',
                 use_skip = True,
                 optimizer='adam',
                 batch_size=10,
                 num_epochs= 20,
                 learning_rate=0.0001,
                 verbose= True):
        super(YourModel, self).__init__(name, width, height, depth, num_blocks, feature_maps, num_classes, drop_rate, batch_norm, is_augmentation, 
                                        activation_func, use_skip, optimizer, batch_size, num_epochs, learning_rate, verbose)
    
    def build_cnn(self):
        #Insert your code here
        class Block(tf.keras.layers.Layer):
            def __init__(self, batch_norm, use_skip, num_filters, drop_rate, activation_func) -> None:
                super(Block, self).__init__()
                #parameters
                self.batch_norm = batch_norm
                self.use_skip = use_skip
                self.activation_func = activation_func
                self.drop_rate = drop_rate
                #layer setup
                self.conv1 = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=3, strides=1, padding='same')
                self.bn1 = tf.keras.layers.BatchNormalization()
                self.act1 = tf.keras.layers.Activation(self.activation_func)
                self.conv2 = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=3, strides=1, padding='same')
                self.bn2 = tf.keras.layers.BatchNormalization()
                self.act2 = tf.keras.layers.Activation(self.activation_func)
                self.mp = tf.keras.layers.AveragePooling2D(pool_size=(2,2), padding='same')
                self.dp = tf.keras.layers.Dropout(rate=self.drop_rate)

            def call(self, X):
                Y = self.conv1(X)
                if self.batch_norm == True:
                    Z = self.bn2(self.conv2(self.act1(self.bn1(Y))))
                    if self.use_skip == True:
                        Z += Y
                    Z = self.act2(Z)
                else:
                    Z = self.conv2(self.act1(Y))
                    if self.use_skip == True:
                        Z += Y
                    Z = self.act2(Z)
        
                return self.dp(self.mp(Z))

        #build model
        self.model = models.Sequential()
        self.model.add(tf.keras.layers.InputLayer(input_shape=(32,32,3)))
                
        #build blocks according to num_blocks
        for i in range(self.num_blocks):
            self.model.add(Block(self.batch_norm, 
                                    self.use_skip, 
                                    self.feature_maps[i], 
                                    self.drop_rate, 
                                    self.activation_func))

        self.model.add(tf.keras.layers.Flatten())
        self.model.add(tf.keras.layers.Dense(self.num_classes, activation='softmax'))
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <span style="color:red">**Question 3.3**</span> **Once writing your own model, you need to compare two cases: (i) *using the skip connection* and (ii) *not using the skip connection*. You should set the instance variable `use_skip` to either `True` or `False`. For your runs, report which case is better and if you confront overfitting in training.**
#
# <div style="text-align: right"> <span style="color:red">[6 points]</span> </div>

# %% [markdown]
# #*Write your report and observation here* <br>
# i) using skip connection <br>
# - Training wise, this model's validation loss and accuracy have progressed significantly at the first few epochs. However, starting from epoch 7 onwards, the rate of increase and rate of decrease for validation accuracy and loss respectively has slowed down even though they are still progressing. As the gap between validation and training loss has barely widened, this model may not be showing any signs of overfitting
# - Test accuracy wise, this model yields a higher accuracy of *0.7000* compared to the model that is not using skip connection
#
# ii) not using skip connection <br>
# - Training wise, this model's validation loss and accuracy seems to have plateaud starting from epoch 5 onwards while the training loss continues to decrease. Therfore, this model exhibits signs of overfitting. <br>
# - Test accuracy wise, this model yield a worse accuracy of *0.6540* compared to the model using skip connection

# %%
our_network_skip = YourModel(name='network1',
                     feature_maps=32,
                     num_classes=len(data_manager.classes),
                     num_blocks=3,
                     drop_rate= 0.0, 
                     batch_norm=True, 
                     use_skip = True,
                     optimizer='adam',
                     learning_rate= 0.001)
our_network_skip.build_cnn()
our_network_skip.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block_18 (Block)            (None, 16, 16, 32)        10400
#
#  block_19 (Block)            (None, 8, 8, 64)          55936
#
#  block_20 (Block)            (None, 4, 4, 128)         222464
#
#  flatten_8 (Flatten)         (None, 2048)              0
#
#  dense_11 (Dense)            (None, 10)                20490
#
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# None

# %%
our_network_skip.fit(data_manager, batch_size=64, num_epochs=20)
# Out:
# Epoch 1/20
# 63/63 [==============================] - 3s 24ms/step - loss: 1.8110 - accuracy: 0.3792 - val_loss: 2.4112 - val_accuracy: 0.1560
# Epoch 2/20
# 63/63 [==============================] - 1s 20ms/step - loss: 1.3783 - accuracy: 0.5232 - val_loss: 2.7197 - val_accuracy: 0.1420
# Epoch 3/20
# 63/63 [==============================] - 1s 19ms/step - loss: 1.1283 - accuracy: 0.6130 - val_loss: 2.8217 - val_accuracy: 0.0960
# Epoch 4/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.9177 - accuracy: 0.6845 - val_loss: 3.6007 - val_accuracy: 0.1500
# Epoch 5/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.7421 - accuracy: 0.7563 - val_loss: 2.9287 - val_accuracy: 0.1640
# Epoch 6/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.5888 - accuracy: 0.8087 - val_loss: 1.9437 - val_accuracy: 0.3760
# Epoch 7/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.4507 - accuracy: 0.8610 - val_loss: 2.3590 - val_accuracy: 0.3640
# Epoch 8/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.3527 - accuracy: 0.8878 - val_loss: 1.6045 - val_accuracy: 0.5140
# Epoch 9/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.2503 - accuracy: 0.9345 - val_loss: 1.5994 - val_accuracy: 0.5400
# Epoch 10/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.1881 - accuracy: 0.9555 - val_loss: 1.7946 - val_accuracy: 0.5420
# Epoch 11/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.1647 - accuracy: 0.9563 - val_loss: 1.6841 - val_accuracy: 0.5980
# Epoch 12/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0874 - accuracy: 0.9860 - val_loss: 1.5103 - val_accuracy: 0.6220
# Epoch 13/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0412 - accuracy: 0.9983 - val_loss: 1.5011 - val_accuracy: 0.6100
# Epoch 14/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0202 - accuracy: 0.9995 - val_loss: 1.4520 - val_accuracy: 0.6400
# Epoch 15/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0122 - accuracy: 0.9990 - val_loss: 1.4971 - val_accuracy: 0.6440
# Epoch 16/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 1.5275 - val_accuracy: 0.6360
# Epoch 17/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.3758 - val_accuracy: 0.6720
# Epoch 18/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 1.4977 - val_accuracy: 0.6480
# Epoch 19/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.4817 - val_accuracy: 0.6660
# Epoch 20/20
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.4728 - val_accuracy: 0.6700

# %%
our_network_skip.plot_progress()

# %%
our_network_skip.compute_accuracy(data_manager.X_test, data_manager.y_test, batch_size=32)
# Out:
# 16/16 [==============================] - 0s 7ms/step - loss: 1.1272 - accuracy: 0.7000
# 0.699999988079071

# %%
our_network_no_skip = YourModel(name='network1',
                     feature_maps=32,
                     num_classes=len(data_manager.classes),
                     num_blocks=3,
                     drop_rate= 0.0, 
                     batch_norm=True, 
                     use_skip = False,
                     optimizer='adam',
                     learning_rate= 0.001)
our_network_no_skip.build_cnn()
our_network_no_skip.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block_12 (Block)            (None, 16, 16, 32)        10400
#
#  block_13 (Block)            (None, 8, 8, 64)          55936
#
#  block_14 (Block)            (None, 4, 4, 128)         222464
#
#  flatten_6 (Flatten)         (None, 2048)              0
#
#  dense_9 (Dense)             (None, 10)                20490
#
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# None

# %%
our_network_no_skip.fit(data_manager, batch_size=32, num_epochs=20)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 3s 16ms/step - loss: 1.8775 - accuracy: 0.3570 - val_loss: 2.4078 - val_accuracy: 0.1700
# Epoch 2/20
# 125/125 [==============================] - 2s 13ms/step - loss: 1.4671 - accuracy: 0.4920 - val_loss: 2.2841 - val_accuracy: 0.1940
# Epoch 3/20
# 125/125 [==============================] - 2s 13ms/step - loss: 1.2008 - accuracy: 0.5850 - val_loss: 2.2977 - val_accuracy: 0.3120
# Epoch 4/20
# 125/125 [==============================] - 2s 13ms/step - loss: 1.0417 - accuracy: 0.6363 - val_loss: 1.5816 - val_accuracy: 0.4880
# Epoch 5/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.8792 - accuracy: 0.6980 - val_loss: 1.5665 - val_accuracy: 0.4920
# Epoch 6/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.7465 - accuracy: 0.7458 - val_loss: 1.3750 - val_accuracy: 0.5820
# Epoch 7/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.6049 - accuracy: 0.7968 - val_loss: 1.3757 - val_accuracy: 0.5780
# Epoch 8/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4757 - accuracy: 0.8413 - val_loss: 1.3636 - val_accuracy: 0.6020
# Epoch 9/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3698 - accuracy: 0.8813 - val_loss: 1.5006 - val_accuracy: 0.5620
# Epoch 10/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3014 - accuracy: 0.9053 - val_loss: 1.3177 - val_accuracy: 0.6280
# Epoch 11/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2120 - accuracy: 0.9360 - val_loss: 1.3300 - val_accuracy: 0.6100
# Epoch 12/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1405 - accuracy: 0.9668 - val_loss: 1.4233 - val_accuracy: 0.6040
# Epoch 13/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1228 - accuracy: 0.9695 - val_loss: 1.5115 - val_accuracy: 0.6260
# Epoch 14/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0893 - accuracy: 0.9785 - val_loss: 1.5077 - val_accuracy: 0.6220
# Epoch 15/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0734 - accuracy: 0.9877 - val_loss: 1.4956 - val_accuracy: 0.6260
# Epoch 16/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0291 - accuracy: 0.9967 - val_loss: 1.3411 - val_accuracy: 0.6580
# Epoch 17/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0235 - accuracy: 0.9965 - val_loss: 1.4078 - val_accuracy: 0.6420
# Epoch 18/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0167 - accuracy: 0.9985 - val_loss: 1.5604 - val_accuracy: 0.6460
# Epoch 19/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0227 - accuracy: 0.9955 - val_loss: 1.6589 - val_accuracy: 0.6220
# Epoch 20/20
# 125/125 [==============================] - 2s 13ms/step - loss: 0.0393 - accuracy: 0.9930 - val_loss: 2.0768 - val_accuracy: 0.5960

# %%
our_network_no_skip.plot_progress()

# %% [markdown]
# <span style="color:red">**Question 3.4**</span> **Now, let us tune the $num\_blocks \in \{2,3,4\}$, $use\_skip \in \{True, False\}$, and $learning\_rate \in \{0.001, 0.0001\}$. Write your code for this tuning and report the result of the best model on the testing set. Note that you need to show your code for tuning and evaluating on the test set to earn the full marks. During tuning, you can set the instance variable `verbose` of your model to `False` for not showing the training details of each epoch.**
#
# <div style="text-align: right"> <span style="color:red">[4 points]</span> </div>

# %% [markdown]
# #*Report the best parameters and the testing accuracy here* <br>
# >The model with <span style=color:red>***num_blocks = 3, use_skip = True, learning_rate = 0.001***</span> yields the best <span style=color:red>***testing accuracy of 0.696***</span>

# %%
#Insert your code here. You can add more cells if necessary
import numpy as np

num_blocks_lst = [2,3,4]
use_skip_lst = [True, False]
learning_rate_lst = [0.001, 0.0001]
best_model = None
best_acc = - np.inf
for block in num_blocks_lst:
    for skip in use_skip_lst:
        for lr in learning_rate_lst:
            model = YourModel(name='network2',
                                feature_maps=32,
                                num_classes=len(data_manager.classes),
                                num_blocks=block,
                                drop_rate= 0.0, 
                                batch_norm=True, 
                                use_skip = skip,
                                optimizer='adam',
                                learning_rate= lr,
                                verbose=False)
            model.build_cnn()
            model.fit(data_manager, batch_size=32, num_epochs=20)
            test_acc = model.compute_accuracy(data_manager.X_test, data_manager.y_test, batch_size=32)
            if test_acc > best_acc:
                best_model = model
            print("Testset accuracy is {} for model with num_blocks={}, use_skip={}, learning_rate={}".format(test_acc, block, skip, lr))
# Out:
# 16/16 [==============================] - 0s 6ms/step - loss: 1.6898 - accuracy: 0.6480
# Testset accuracy is 0.6480000019073486 for model with num_blocks=2, use_skip=True, learning_rate=0.001
# 16/16 [==============================] - 0s 6ms/step - loss: 1.2532 - accuracy: 0.5560
# Testset accuracy is 0.5559999942779541 for model with num_blocks=2, use_skip=True, learning_rate=0.0001
# 16/16 [==============================] - 0s 7ms/step - loss: 1.3817 - accuracy: 0.6600
# Testset accuracy is 0.6600000262260437 for model with num_blocks=2, use_skip=False, learning_rate=0.001
# 16/16 [==============================] - 0s 6ms/step - loss: 1.2237 - accuracy: 0.5840
# Testset accuracy is 0.5839999914169312 for model with num_blocks=2, use_skip=False, learning_rate=0.0001
# 16/16 [==============================] - 0s 8ms/step - loss: 1.4657 - accuracy: 0.6760
# Testset accuracy is 0.6759999990463257 for model with num_blocks=3, use_skip=True, learning_rate=0.001
# 16/16 [==============================] - 0s 7ms/step - loss: 1.1286 - accuracy: 0.6360
# Testset accuracy is 0.6359999775886536 for model with num_blocks=3, use_skip=True, learning_rate=0.0001
# 16/16 [==============================] - 0s 8ms/step - loss: 1.7255 - accuracy: 0.5860
# Testset accuracy is 0.5860000252723694 for model with num_blocks=3, use_skip=False, learning_rate=0.001
# 16/16 [==============================] - 0s 8ms/step - loss: 1.1849 - accuracy: 0.6140
# Testset accuracy is 0.6140000224113464 for model with num_blocks=3, use_skip=False, learning_rate=0.0001
# 16/16 [==============================] - 0s 10ms/step - loss: 1.5435 - accuracy: 0.6760
# Testset accuracy is 0.6759999990463257 for model with num_blocks=4, use_skip=True, learning_rate=0.001
# 16/16 [==============================] - 0s 8ms/step - loss: 1.5815 - accuracy: 0.6160
# Testset accuracy is 0.6159999966621399 for model with num_blocks=4, use_skip=True, learning_rate=0.0001
# 16/16 [==============================] - 0s 9ms/step - loss: 1.8830 - accuracy: 0.6360
# Testset accuracy is 0.6359999775886536 for model with num_blocks=4, use_skip=False, learning_rate=0.001
# 16/16 [==============================] - 0s 9ms/step - loss: 1.4172 - accuracy: 0.6200
# Testset accuracy is 0.6200000047683716 for model with num_blocks=4, use_skip=False, learning_rate=0.0001

# %% [markdown]
# <span style="color:red">**Question 3.5**</span> **We now try to apply data augmentation to improve the performance. Extend the code of the class `YourModel` so that if the attribute `is_augmentation` is set to `True`, we apply the data augmentation. Also you need to incorporate early stopping to your training process. Specifically, you early stop the training if the valid accuracy cannot increase in three consecutive epochs.**
#
# <div style="text-align: right"> <span style="color:red">[4 points]</span> </div>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Write your code in the cell below. Hint that you can rewrite the code of the `fit` method to apply the data augmentation. In addition, you can copy the code of `build_cnn` method above to reuse here.

# %%
class YourModel(DefaultModel):
    def __init__(self,
                 name='network1',
                 width=32, height=32, depth=3,
                 num_blocks=2,
                 feature_maps=32,
                 num_classes=4, 
                 drop_rate=0.2,
                 batch_norm = None,
                 is_augmentation = False,
                 activation_func='relu',
                 use_skip = True,
                 optimizer='adam',
                 batch_size=10,
                 num_epochs= 20,
                 learning_rate=0.0001):
        super(YourModel, self).__init__(name, width, height, depth, num_blocks, feature_maps, num_classes, drop_rate, batch_norm, is_augmentation, 
                                        activation_func, use_skip, optimizer, batch_size, num_epochs, learning_rate)
    
    def build_cnn(self):
        #reuse code of previous section here
        #Insert your code here
        class Block(tf.keras.layers.Layer):
            def __init__(self, batch_norm, use_skip, num_filters, drop_rate, activation_func) -> None:
                super(Block, self).__init__()
                #parameters
                self.batch_norm = batch_norm
                self.use_skip = use_skip
                self.activation_func = activation_func
                self.drop_rate = drop_rate
                #layer setup
                self.conv1 = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=3, strides=1, padding='same')
                self.bn1 = tf.keras.layers.BatchNormalization()
                self.act1 = tf.keras.layers.Activation(self.activation_func)
                self.conv2 = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=3, strides=1, padding='same')
                self.bn2 = tf.keras.layers.BatchNormalization()
                self.act2 = tf.keras.layers.Activation(self.activation_func)
                self.mp = tf.keras.layers.AveragePooling2D(pool_size=(2,2), padding='same')
                self.dp = tf.keras.layers.Dropout(rate=self.drop_rate)

            def call(self, X):
                Y = self.conv1(X)
                if self.batch_norm == True:
                    Z = self.bn2(self.conv2(self.act1(self.bn1(Y))))
                    if self.use_skip == True:
                        Z += Y
                    Z = self.act2(Z)
                else:
                    Z = self.conv2(self.act1(Y))
                    if self.use_skip == True:
                        Z += Y
                    Z = self.act2(Z)
        
                return self.dp(self.mp(Z))

        #build model
        self.model = models.Sequential()
        self.model.add(tf.keras.layers.InputLayer(input_shape=(32,32,3)))
                
        #build blocks according to num_blocks
        for i in range(self.num_blocks):
            self.model.add(Block(self.batch_norm, 
                                    self.use_skip, 
                                    self.feature_maps[i], 
                                    self.drop_rate, 
                                    self.activation_func))

        self.model.add(tf.keras.layers.Flatten())
        self.model.add(tf.keras.layers.Dense(self.num_classes, activation='softmax'))
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    def fit(self, data_manager, batch_size=None, num_epochs=None):
        #insert your code here
        batch_size = self.batch_size if batch_size is None else batch_size
        num_epochs = self.num_epochs if num_epochs is None else num_epochs
        early_stop = EarlyStopping(patience=3, monitor='val_accuracy', mode='max')
        self.model.compile(optimizer=self.optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

        if self.is_augmentation == True:
            datagen = ImageDataGenerator(horizontal_flip=True, width_shift_range=0.1, height_shift_range=0.1, rotation_range=3)
            datagen.fit(data_manager.X_train)
            train_data = datagen.flow(data_manager.X_train, data_manager.y_train, batch_size=batch_size)
            self.history = self.model.fit(train_data, validation_data = (data_manager.X_valid, data_manager.y_valid), 
                                      epochs = num_epochs, verbose= self.verbose, callbacks=[early_stop])
        else:
            self.history = self.model.fit(x = data_manager.X_train, y = data_manager.y_train, validation_data = (data_manager.X_valid, data_manager.y_valid), 
                                      epochs = num_epochs, batch_size = batch_size, verbose= self.verbose, callbacks=[early_stop])

# %% [markdown]
# <span style="color:red">**Question 3.6**</span> **Leverage your best model with the data augmentation and try to observe the difference in performance between using data augmentation and non-using it.**
#
# <div style="text-align: right"> <span style="color:red">[4 points]</span> </div>

# %% [markdown]
# #*Write your answer and observation here*<br>
#
# > ### Answer:
# > - The model which uses data augmentation has show a better test accuracy of ***0.666*** compared to a test accuracy of ***0.626*** produced by the model which does not use data augmentation.
# >
# > - As early stopping is used here. Model with augmentations ran a total of 16 epochs before being stopped while model with no augmentation only ran a total of 11 epochs. This means that the model with no data augmentation has shown signs of overfitting early on and the validation accuracy has not decreased steadily compared to model with data augmentation
# >
# > - Both validation loss and accuracy of the model with no augmentation also seems to have plateaud starting from epoch 5 onwards which led to an early stop

# %%
#Insert your code here. You can add more cells if necessary
aug_model = YourModel(name='network3',
                                feature_maps=32,
                                num_classes=len(data_manager.classes),
                                num_blocks=3,
                                drop_rate= 0.0, 
                                batch_norm=True, 
                                use_skip = True,
                                optimizer='adam',
                                learning_rate= 0.001,
                                is_augmentation=True)
aug_model.build_cnn()
aug_model.fit(data_manager, batch_size=32, num_epochs=20)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 4s 25ms/step - loss: 1.8690 - accuracy: 0.3600 - val_loss: 2.3938 - val_accuracy: 0.1300
# Epoch 2/20
# 125/125 [==============================] - 3s 22ms/step - loss: 1.5663 - accuracy: 0.4520 - val_loss: 2.2065 - val_accuracy: 0.2220
# Epoch 3/20
# 125/125 [==============================] - 3s 23ms/step - loss: 1.3861 - accuracy: 0.5170 - val_loss: 2.3582 - val_accuracy: 0.2680
# Epoch 4/20
# 125/125 [==============================] - 3s 22ms/step - loss: 1.2624 - accuracy: 0.5667 - val_loss: 1.5893 - val_accuracy: 0.4580
# Epoch 5/20
# 125/125 [==============================] - 3s 23ms/step - loss: 1.1673 - accuracy: 0.5928 - val_loss: 1.7020 - val_accuracy: 0.4420
# Epoch 6/20
# 125/125 [==============================] - 3s 22ms/step - loss: 1.0712 - accuracy: 0.6230 - val_loss: 3.0690 - val_accuracy: 0.3600
# Epoch 7/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.9936 - accuracy: 0.6582 - val_loss: 1.2833 - val_accuracy: 0.5760
# Epoch 8/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.9486 - accuracy: 0.6715 - val_loss: 1.4780 - val_accuracy: 0.5400
# Epoch 9/20
# 125/125 [==============================] - 3s 23ms/step - loss: 0.8577 - accuracy: 0.7088 - val_loss: 1.2912 - val_accuracy: 0.5720
# Epoch 10/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.8209 - accuracy: 0.7188 - val_loss: 1.2365 - val_accuracy: 0.6020
# Epoch 11/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.7746 - accuracy: 0.7345 - val_loss: 1.5629 - val_accuracy: 0.5360
# Epoch 12/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.7043 - accuracy: 0.7558 - val_loss: 1.2373 - val_accuracy: 0.6080
# Epoch 13/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.6928 - accuracy: 0.7623 - val_loss: 1.1489 - val_accuracy: 0.6420
# Epoch 14/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.6226 - accuracy: 0.7868 - val_loss: 1.3511 - val_accuracy: 0.5880
# Epoch 15/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.6170 - accuracy: 0.7840 - val_loss: 1.2506 - val_accuracy: 0.6060
# Epoch 16/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.5641 - accuracy: 0.7993 - val_loss: 1.2450 - val_accuracy: 0.6240

# %%
test_acc = aug_model.compute_accuracy(data_manager.X_test, data_manager.y_test, batch_size=32)
# Out:
# 16/16 [==============================] - 0s 7ms/step - loss: 1.0861 - accuracy: 0.6660

# %%
aug_model.plot_progress()

# %%
no_aug_model = YourModel(name='network3',
                                feature_maps=32,
                                num_classes=len(data_manager.classes),
                                num_blocks=3,
                                drop_rate= 0.0, 
                                batch_norm=True, 
                                use_skip = True,
                                optimizer='adam',
                                learning_rate= 0.001,
                                is_augmentation=False)
no_aug_model.build_cnn()
no_aug_model.fit(data_manager, batch_size=32, num_epochs=20)
test_acc = no_aug_model.compute_accuracy(data_manager.X_test, data_manager.y_test, batch_size=32)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 3s 18ms/step - loss: 1.8126 - accuracy: 0.3803 - val_loss: 2.4283 - val_accuracy: 0.1920
# Epoch 2/20
# 125/125 [==============================] - 2s 14ms/step - loss: 1.3652 - accuracy: 0.5332 - val_loss: 2.2026 - val_accuracy: 0.2360
# Epoch 3/20
# 125/125 [==============================] - 2s 15ms/step - loss: 1.0902 - accuracy: 0.6295 - val_loss: 2.1263 - val_accuracy: 0.2800
# Epoch 4/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.9191 - accuracy: 0.6858 - val_loss: 1.6756 - val_accuracy: 0.4460
# Epoch 5/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.7329 - accuracy: 0.7465 - val_loss: 1.4986 - val_accuracy: 0.5200
# Epoch 6/20
# 125/125 [==============================] - 2s 14ms/step - loss: 0.6048 - accuracy: 0.8018 - val_loss: 1.3061 - val_accuracy: 0.5920
# Epoch 7/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4428 - accuracy: 0.8608 - val_loss: 1.5404 - val_accuracy: 0.5840
# Epoch 8/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3519 - accuracy: 0.8905 - val_loss: 1.5416 - val_accuracy: 0.6340
# Epoch 9/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.2469 - accuracy: 0.9305 - val_loss: 1.3642 - val_accuracy: 0.6280
# Epoch 10/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1785 - accuracy: 0.9528 - val_loss: 1.6045 - val_accuracy: 0.5880
# Epoch 11/20
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1414 - accuracy: 0.9630 - val_loss: 1.5247 - val_accuracy: 0.6220
# 16/16 [==============================] - 0s 7ms/step - loss: 1.3871 - accuracy: 0.6260

# %%
no_aug_model.plot_progress()

# %% [markdown]
# <span style="color:red">**Question 3.7**</span> **Exploring Data Mixup Technique for Improving Generalization Ability.**
#
# <div style="text-align: right"> <span style="color:red">[4 points]</span> </div>
#
# Data mixup is another super-simple technique used to boost the generalization ability of deep learning models. You need to incoroporate data mixup technique to the above deep learning model and experiment its performance. There are some papers and documents for data mixup as follows:
# - Main paper for data mixup [link for main paper](https://openreview.net/pdf?id=r1Ddp1-Rb) and a good article [article link](https://www.inference.vc/mixup-data-dependent-data-augmentation/).
#
# You need to extend your model developed above, train a model using data mixup, and write your observations and comments about the result.

# %% [markdown]
# #*Write your answer and observation here*
#
# > ### Answer:
# >
# > - The implementation of data mix up did not improve the test accuracy. However, the validation loss and accuracy is much closer to the training loss and accuracy

# %%
#Insert your code here. You can add more cells if necessary
class MixupAugGenerator(tf.keras.preprocessing.image.NumpyArrayIterator):
    def __init__(self, X, y, img_gen, batch_size, alpha, shuffle=True):
        super(MixupAugGenerator, self).__init__(X, y, img_gen, batch_size, shuffle)
        self.alpha = alpha
        self.batch_size = batch_size
        self.img_gen = img_gen
        self.img_gen.fit(X)
        self.data1 = self.img_gen.flow(X, y, self.batch_size)
        self.data2 = self.img_gen.flow(X, y, self.batch_size)
 
    def next(self):
        #calculate lambda value
        l_val = np.random.beta(self.alpha, self.alpha+1, self.batch_size)

        l_x = l_val.reshape(self.batch_size, 1, 1, 1)
        l_y = l_val.reshape(self.batch_size, 1)

        X1, y1 = self.data1.next()
        X2, y2 = self.data2.next()

        X = X1 * l_x + (1-l_x) * X2
        # y = y1 * l_y + (1-l_y) * y2
        y = y1 
        
        return X, y

# %%
class YourModel(DefaultModel):
    def __init__(self,
                 name='network1',
                 width=32, height=32, depth=3,
                 num_blocks=2,
                 feature_maps=32,
                 num_classes=4, 
                 drop_rate=0.2,
                 batch_norm = None,
                 is_augmentation = False,
                 activation_func='relu',
                 use_skip = True,
                 optimizer='adam',
                 batch_size=10,
                 num_epochs= 20,
                 learning_rate=0.0001):
        super(YourModel, self).__init__(name, width, height, depth, num_blocks, feature_maps, num_classes, drop_rate, batch_norm, is_augmentation, 
                                        activation_func, use_skip, optimizer, batch_size, num_epochs, learning_rate)
    
    def build_cnn(self):
        #reuse code of previous section here
        #Insert your code here
        class Block(tf.keras.layers.Layer):
            def __init__(self, batch_norm, use_skip, num_filters, drop_rate, activation_func) -> None:
                super(Block, self).__init__()
                #parameters
                self.batch_norm = batch_norm
                self.use_skip = use_skip
                self.activation_func = activation_func
                self.drop_rate = drop_rate
                #layer setup
                self.conv1 = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=3, strides=1, padding='same')
                self.bn1 = tf.keras.layers.BatchNormalization()
                self.act1 = tf.keras.layers.Activation(self.activation_func)
                self.conv2 = tf.keras.layers.Conv2D(filters=num_filters, kernel_size=3, strides=1, padding='same')
                self.bn2 = tf.keras.layers.BatchNormalization()
                self.act2 = tf.keras.layers.Activation(self.activation_func)
                self.mp = tf.keras.layers.AveragePooling2D(pool_size=(2,2), padding='same')
                self.dp = tf.keras.layers.Dropout(rate=self.drop_rate)

            def call(self, X):
                Y = self.conv1(X)
                if self.batch_norm == True:
                    Z = self.bn2(self.conv2(self.act1(self.bn1(Y))))
                    if self.use_skip == True:
                        Z += Y
                    Z = self.act2(Z)
                else:
                    Z = self.conv2(self.act1(Y))
                    if self.use_skip == True:
                        Z += Y
                    Z = self.act2(Z)
        
                return self.dp(self.mp(Z))

        #build model
        self.model = models.Sequential()
        self.model.add(tf.keras.layers.InputLayer(input_shape=(32,32,3)))
                
        #build blocks according to num_blocks
        for i in range(self.num_blocks):
            self.model.add(Block(self.batch_norm, 
                                    self.use_skip, 
                                    self.feature_maps[i], 
                                    self.drop_rate, 
                                    self.activation_func))

        self.model.add(tf.keras.layers.Flatten())
        self.model.add(tf.keras.layers.Dense(self.num_classes, activation='softmax'))
        self.model.compile(optimizer=self.optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    def fit(self, data_manager, batch_size=None, num_epochs=None):
        #insert your code here
        batch_size = self.batch_size if batch_size is None else batch_size
        num_epochs = self.num_epochs if num_epochs is None else num_epochs
        early_stop = EarlyStopping(patience=3, monitor='val_accuracy', mode='max')
        self.model.compile(optimizer=self.optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

        if self.is_augmentation == True:
            aug_gen = ImageDataGenerator(horizontal_flip=True, width_shift_range=0.2, height_shift_range=0.2, rotation_range=3)
            datagen = MixupAugGenerator(data_manager.X_train, tf.one_hot(data_manager.y_train, depth=self.num_classes), aug_gen, batch_size=batch_size, alpha=0.1)
            self.history = self.model.fit(datagen, validation_data = (data_manager.X_valid, tf.one_hot(data_manager.y_valid, depth=self.num_classes)), 
                                      epochs = num_epochs, verbose= self.verbose, callbacks=[early_stop])
        else:
            self.history = self.model.fit(x = data_manager.X_train, y = tf.one_hot(data_manager.y_train, depth=self.num_classes), validation_data = (data_manager.X_valid, tf.one_hot(data_manager.y_valid, depth=self.num_classes)), 
                                      epochs = num_epochs, batch_size = batch_size, verbose= self.verbose, callbacks=[early_stop])

# %%
mixup_model = YourModel(name='network4',
                                feature_maps=32,
                                num_classes=len(data_manager.classes),
                                num_blocks=3,
                                drop_rate= 0.0, 
                                batch_norm=True, 
                                use_skip = True,
                                optimizer='adam',
                                learning_rate= 0.001,
                                is_augmentation=True)
mixup_model.build_cnn()
mixup_model.fit(data_manager, batch_size=32, num_epochs=20)
test_acc = mixup_model.compute_accuracy(data_manager.X_test, tf.one_hot(data_manager.y_test, depth=len(data_manager.classes)), batch_size=32)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 5s 26ms/step - loss: 1.9705 - accuracy: 0.3043 - val_loss: 2.8927 - val_accuracy: 0.1100
# Epoch 2/20
# 125/125 [==============================] - 3s 23ms/step - loss: 1.6606 - accuracy: 0.4072 - val_loss: 2.1004 - val_accuracy: 0.2900
# Epoch 3/20
# 125/125 [==============================] - 3s 24ms/step - loss: 1.5324 - accuracy: 0.4627 - val_loss: 2.2644 - val_accuracy: 0.2360
# Epoch 4/20
# 125/125 [==============================] - 3s 25ms/step - loss: 1.4323 - accuracy: 0.5070 - val_loss: 1.6236 - val_accuracy: 0.4200
# Epoch 5/20
# 125/125 [==============================] - 3s 24ms/step - loss: 1.3046 - accuracy: 0.5452 - val_loss: 1.5362 - val_accuracy: 0.4600
# Epoch 6/20
# 125/125 [==============================] - 3s 27ms/step - loss: 1.2431 - accuracy: 0.5732 - val_loss: 1.8506 - val_accuracy: 0.4780
# Epoch 7/20
# 125/125 [==============================] - 3s 24ms/step - loss: 1.2142 - accuracy: 0.5775 - val_loss: 2.0106 - val_accuracy: 0.4520
# Epoch 8/20
# 125/125 [==============================] - 3s 24ms/step - loss: 1.1507 - accuracy: 0.6045 - val_loss: 1.6348 - val_accuracy: 0.4720
# Epoch 9/20
# 125/125 [==============================] - 3s 25ms/step - loss: 1.0653 - accuracy: 0.6280 - val_loss: 1.2671 - val_accuracy: 0.5740
# Epoch 10/20
# 125/125 [==============================] - 3s 24ms/step - loss: 1.0125 - accuracy: 0.6530 - val_loss: 1.3920 - val_accuracy: 0.5560
# Epoch 11/20
# 125/125 [==============================] - 3s 23ms/step - loss: 0.9928 - accuracy: 0.6587 - val_loss: 1.2260 - val_accuracy: 0.6020
# Epoch 12/20
# 125/125 [==============================] - 3s 25ms/step - loss: 0.9296 - accuracy: 0.6793 - val_loss: 1.3080 - val_accuracy: 0.5660
# Epoch 13/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.8910 - accuracy: 0.6885 - val_loss: 1.5441 - val_accuracy: 0.5360
# Epoch 14/20
# 125/125 [==============================] - 3s 22ms/step - loss: 0.8763 - accuracy: 0.6910 - val_loss: 1.5169 - val_accuracy: 0.5440
# 16/16 [==============================] - 0s 8ms/step - loss: 1.2975 - accuracy: 0.5720

# %%
mixup_model.plot_progress()

# %%
def show_images(X, tile_shape=(5, 5)):
        plt.clf()
        fig, ax = plt.subplots(tile_shape[0], tile_shape[1], figsize=(2.5 * tile_shape[1], 2.5 * tile_shape[0]))
        idx = 0

        for i in range(tile_shape[0]):
            for j in range(tile_shape[1]):
                ax[i, j].imshow((X[idx] + 1.0)/2)
                ax[i, j].grid(False)
                ax[i, j].axis('off')
                idx +=1
        plt.show()

# %% [markdown]
# <span style="color:red">**Question 3.8**</span> **Attack your best obtained model with PGD, MIM, and FGSM attacks with $\epsilon= 0.0313, k=20, \eta= 0.002$ on the testing set. Write the code for the attacks and report the robust accuracies. Also choose a random set of 20 clean images in the testing set and visualize the original and attacked images.**
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>

# %%
import random

# %%
#function for 20 random images 
def random_image(X1, X2, tile_shape=(4,5)):
    plt.clf()
    fig1, ax1 = plt.subplots(tile_shape[0], tile_shape[1], figsize=(2.5 * tile_shape[1], 2.5 * tile_shape[0]))
    fig2, ax2 = plt.subplots(tile_shape[0], tile_shape[1], figsize=(2.5 * tile_shape[1], 2.5 * tile_shape[0]))
    fig1.suptitle('Attacked Images', fontsize = 24)
    fig2.suptitle('Original Images', fontsize = 24)
    idx = random.sample(range(0,500), 20)
    for i in range(tile_shape[0]):
        for j in range(tile_shape[1]):
            cur_idx = idx.pop(0)
            ax1[i, j].imshow((X1[cur_idx] + 1.0)/2)
            ax1[i, j].grid(False)
            ax1[i, j].axis('off')

            ax2[i, j].imshow((X2[cur_idx] + 1.0)/2)
            ax2[i, j].grid(False)
            ax2[i, j].axis('off')
    

    plt.show()

# %%
#Insert your code here. You can add more cells if necessary
#Attack functions
#FGSM Attack
def fgsm_attack(model, input_image, input_label=None, 
               epsilon=0.3, 
               clip_value_min=0., 
               clip_value_max=1.0, 
               soft_label=False,
               from_logits=True): 
    """
    Args: 
        model: pretrained model 
        input_image: original (clean) input image (tensor)
        input_label: original label (tensor, categorical representation)
        epsilon: perturbation boundary 
        clip_value_min, clip_value_max: range of valid input 
        from_logits = True: attack from logits otherwise attack from prediction probabilites
    Note: 
        we expect the output of model should be logits vector 
    """
    
    loss_fn = tf.keras.losses.sparse_categorical_crossentropy # compute CE loss from logits or prediction probabilities
    
    if type(input_image) is np.ndarray: 
        input_image = tf.convert_to_tensor(input_image)
    
    if type(input_label) is np.ndarray: 
        input_label = tf.convert_to_tensor(input_label)
        
    with tf.GradientTape() as tape: 
        tape.watch(input_image)
        output = model(input_image)
        if not soft_label:
            loss = loss_fn(input_label, output, from_logits=from_logits) # use ground-truth label to attack
        else: 
            pred_label = tf.math.argmax(output, axis=1) # use predicted label to attack
            loss = loss_fn(pred_label, output, from_logits=from_logits)

    gradient = tape.gradient(loss, input_image) # get the gradients of the loss w.r.t. the input image 
    adv_image = input_image + epsilon * tf.sign(gradient) # get the final adversarial examples 
    adv_image = tf.clip_by_value(adv_image, clip_value_min, clip_value_max) # clip to a valid range  
    adv_image = tf.stop_gradient(adv_image) # stop the gradient to make the adversarial image as a constant input
    return adv_image

# %%
#Attack test data
x_fgsm = fgsm_attack(mixup_model.model, data_manager.X_test, soft_label=True, from_logits=False)

#test data accuracy
pred_fgsm = mixup_model.compute_accuracy(x_fgsm, tf.one_hot(data_manager.y_test, depth=len(data_manager.classes)), batch_size=32)
print('Test data accuracy for FGSM is {}'.format(pred_fgsm))
# Out:
# 16/16 [==============================] - 0s 7ms/step - loss: 5.2809 - accuracy: 0.1420
# Test data accuracy for FGSM is 0.1420000046491623

# %%
#Print images
random_image(x_fgsm.numpy(), data_manager.X_test)

# %%
#PGD Attack
def pgd_attack(model, input_image, input_label= None, 
              epsilon=0.0313, 
              num_steps=20, 
              step_size=0.002, 
              clip_value_min=0., 
              clip_value_max=1.0, 
              soft_label=False,
              from_logits= True): 
    """
    Args: 
        model: pretrained model 
        input_image: original (clean) input image (tensor)
        input_label: original label (tensor, categorical representation)
        epsilon: perturbation boundary 
        num_steps: number of attack steps 
        step_size: size of each move in each attack step 
        clip_value_min, clip_value_max: range of valid input 
        from_logits = True: attack from logits otherwise attack from prediction probabilites
    Note: 
        we expect the output of model should be logits vector  
    """       
    
    loss_fn = tf.keras.losses.sparse_categorical_crossentropy  #compute CE loss from logits or prediction probabilities
    
    if type(input_image) is np.ndarray: 
        input_image = tf.convert_to_tensor(input_image)
    
    if type(input_label) is np.ndarray: 
        input_label = tf.convert_to_tensor(input_label)
        
    # random initialization around input_image 
    random_noise = tf.random.uniform(shape=input_image.shape, minval=-epsilon, maxval=epsilon, dtype='float64')
    adv_image = input_image + random_noise

    for _ in range(num_steps): 
        with tf.GradientTape(watch_accessed_variables=False) as tape: 
            tape.watch(adv_image)
            adv_output = model(adv_image)
            if not soft_label:
                loss = loss_fn(input_label, adv_output, from_logits= from_logits) # use ground-truth label to attack
            else: 
                pred_label = tf.math.argmax(adv_output, axis=1)
                loss = loss_fn(pred_label, adv_output, from_logits= from_logits) # use predicted label to attack

        gradient = tape.gradient(loss, adv_image) # get the gradient of the loss w.r.t. the current point 
        adv_image = adv_image + step_size * tf.sign(gradient) # move current adverarial example along the gradient direction with step size is eta 
        adv_image = tf.clip_by_value(adv_image, input_image-epsilon, input_image+epsilon) # clip to a valid boundary  
        adv_image = tf.clip_by_value(adv_image, clip_value_min, clip_value_max)  # clip to a valid range
        adv_image = tf.stop_gradient(adv_image) # stop the gradient to make the adversarial image as a constant input 
    return adv_image

# %%
#Attack test data
x_pgd = pgd_attack(mixup_model.model, data_manager.X_test, soft_label=True, from_logits=False)

#test data accuracy
pred_pgd = mixup_model.compute_accuracy(x_pgd, tf.one_hot(data_manager.y_test, depth=len(data_manager.classes)), batch_size=32)
print('Test data accuracy for PGD Attack is {}'.format(pred_pgd))
# Out:
# 16/16 [==============================] - 0s 7ms/step - loss: 2.0372 - accuracy: 0.3000
# Test data accuracy for PGD Attack is 0.30000001192092896

# %%
#Print images
random_image(x_pgd.numpy(), data_manager.X_test)

# %%
#MIM Attack
def mim_attack(model, input_image, input_label= None, 
              epsilon=0.3, 
              gamma= 0.9,
              num_steps=20, 
              step_size=0.01, 
              clip_value_min=0., 
              clip_value_max=1.0, 
              soft_label=False,
              from_logits= True): 
    """
    Args: 
        model: pretrained model 
        input_image: original (clean) input image (tensor)
        input_label: original label (tensor, categorical representation)
        epsilon: perturbation boundary 
        gamma: momentum decay
        num_steps: number of attack steps 
        step_size: size of each move in each attack step 
        clip_value_min, clip_value_max: range of valid input 
        from_logits = True: attack from logits otherwise attack from prediction probabilites
    Note: 
        we expect the output of model should be logits vector  
    """       
    
    loss_fn = tf.keras.losses.sparse_categorical_crossentropy # compute CE loss from logits or prediction probabilities
    
    if type(input_image) is np.ndarray: 
        input_image = tf.convert_to_tensor(input_image)
    
    if type(input_label) is np.ndarray: 
        input_label = tf.convert_to_tensor(input_label)
        
    # random initialization around input_image 
    random_noise = tf.random.uniform(shape=input_image.shape, minval=-epsilon, maxval=epsilon, dtype='float64')
    adv_image = input_image + random_noise
    adv_noise = random_noise

    for _ in range(num_steps): 
        with tf.GradientTape(watch_accessed_variables=False) as tape: 
            tape.watch(adv_image)
            adv_output = model(adv_image)
            if not soft_label:
                loss = loss_fn(input_label, adv_output, from_logits=from_logits) # use ground-truth label to attack
            else: 
                pred_label = tf.math.argmax(adv_output, axis=1)
                loss = loss_fn(pred_label, adv_output, from_logits=from_logits) # use predicted label to attack

        gradient = tape.gradient(loss, adv_image) # get the gradient of the loss w.r.t. the current point 
        adv_image_new = adv_image + step_size * tf.sign(gradient) # move current adverarial example along the gradient direction with step size is eta 
        adv_image_new = tf.clip_by_value(adv_image_new, input_image-epsilon, input_image+epsilon) # clip to a valid boundary  
        adv_image_new = tf.clip_by_value(adv_image_new, clip_value_min, clip_value_max) # clip to a valid range
        adv_noise = gamma*adv_noise + (1-gamma)*(adv_image_new - adv_image)
        adv_image = adv_image_new
        adv_image = tf.stop_gradient(adv_image) # stop the gradient to make the adversarial image as a constant input 
    adv_image = adv_image + adv_noise
    adv_image = tf.clip_by_value(adv_image, input_image-epsilon, input_image+epsilon) # clip to a valid boundary  
    adv_image = tf.clip_by_value(adv_image, clip_value_min, clip_value_max) # clip to a valid range
    return adv_image

# %%
#Attack test data
x_mim = mim_attack(mixup_model.model, data_manager.X_test, soft_label=True, from_logits=False)

#test data accuracy
pred_mim = mixup_model.compute_accuracy(x_mim, tf.one_hot(data_manager.y_test, depth=len(data_manager.classes)), batch_size=32)
print('Test data accuracy for MIM Attack is {}'.format(pred_mim))
# Out:
# 16/16 [==============================] - 0s 8ms/step - loss: 2.2885 - accuracy: 0.1680
# Test data accuracy for MIM Attack is 0.1679999977350235

# %%
#Print images
random_image(x_mim.numpy(), data_manager.X_test)

# %% [markdown]
# <span style="color:red">**Question 3.9**</span> **Train a robust model using adversarial training with PGD ${\epsilon= 0.0313, k=10, \eta= 0.002}$. Write the code for the adversarial training and report the robust accuracies. After finishing the training, you need to store your best robust model in the folder `./models` and load the model to evaluate the robust accuracies for PGD, MIM, and FGSM attacks with $\epsilon= 0.0313, k=20, \eta= 0.002$ on the testing set.**
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>

# %%
from sklearn.metrics import accuracy_score

# %%
#Insert your code here. You can add more cells if necessary
#model build
def_model = aug_model.model

#data preparation
tr_data = tf.data.Dataset.from_tensor_slices((data_manager.X_train, tf.one_hot(data_manager.y_train, depth=len(data_manager.classes)))).shuffle(4000).batch(32)
te_data = tf.data.Dataset.from_tensor_slices((data_manager.X_test, tf.one_hot(data_manager.y_test, depth=len(data_manager.classes)))).batch(32)

opt = tf.optimizers.Adam(learning_rate=0.001)
loss_func = tf.nn.softmax_cross_entropy_with_logits

#metrics
tr_loss = tf.metrics.Mean(name='train_loss')
te_acc = tf.metrics.CategoricalAccuracy()
te_acc_pgd = tf.metrics.CategoricalAccuracy()

# %%
def adv_train(X, adv_X, y):
    with tf.GradientTape() as t:
        pred_logit = def_model(X)
        pred_logit_adv = def_model(adv_X)
        loss = (loss_func(y, pred_logit) + loss_func(y, pred_logit_adv))/2
        grad = t.gradient(loss, def_model.trainable_variables)
        opt.apply_gradients(zip(grad, def_model.trainable_variables))
    return loss

# %%
epochs = 5 # number of epochs
for epoch in range(epochs):
    progress_bar_train = tf.keras.utils.Progbar(4000, verbose=2)
    for (x, y) in tr_data:
        
        adv_X = pgd_attack(def_model, x, y, 0.0313, 10, 0.002, from_logits=False, soft_label=True)
        loss = adv_train(x, adv_X, y)
        y_pred = def_model(x)
        te_acc(y, y_pred)
        tr_loss(loss)
        progress_bar_train.add(x.shape[0], values=[('loss', tr_loss.result()), ("acc (%)", te_acc.result() * 100)])

#save model
def_model.save('./models/robust_model')
# Out:
# 4000/4000 - 48s - loss: 1.8863 - acc (%): 79.0403 - 48s/epoch - 12ms/step
# 4000/4000 - 45s - loss: 1.8422 - acc (%): 79.4100 - 45s/epoch - 11ms/step
# 4000/4000 - 46s - loss: 1.8203 - acc (%): 80.3529 - 46s/epoch - 11ms/step
# 4000/4000 - 45s - loss: 1.8036 - acc (%): 81.4239 - 45s/epoch - 11ms/step
# 4000/4000 - 45s - loss: 1.7869 - acc (%): 82.6772 - 45s/epoch - 11ms/step
# WARNING:absl:Found untraced functions such as conv2d_220_layer_call_fn, conv2d_220_layer_call_and_return_conditional_losses, _jit_compiled_convolution_op, activation_212_layer_call_fn, activation_212_layer_call_and_return_conditional_losses while saving (showing 5 of 36). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/robust_model\assets
# INFO:tensorflow:Assets written to: ./models/robust_model\assets

# %%
#load saved robust model
def_model = tf.keras.models.load_model('./models/robust_model/')

# %%
#Evaluation accuracy for PGD Attack
pgd_y = []
y_true = []
for X, y in te_data:
    X_pgd = pgd_attack(def_model, X, y, 0.0313, 20, 0.002, from_logits=False, soft_label=True)
    y_pgd = np.argmax(def_model(X_pgd).numpy(), 1)
    pgd_y.append(y_pgd[0].tolist())
    y_true.append(y.numpy()[0].tolist())

te_pgd_acc = accuracy_score(np.argmax(y_true, axis=1).tolist(), pgd_y)
print("Test pgd accuracy:{}".format(te_pgd_acc))
# Out:
# Test pgd accuracy:0.6875

# %%
#Evaluation accuracy for MIM Attack
mim_y = []
y_true = []
for X, y in te_data:
    X_mim = mim_attack(def_model, X, y, epsilon=0.0313, num_steps=20, step_size=0.002, from_logits=False, soft_label=True)
    y_mim = np.argmax(def_model(X_mim).numpy(), 1)
    mim_y.append(y_mim[0].tolist())
    y_true.append(y.numpy()[0].tolist())

te_mim_acc = accuracy_score(np.argmax(y_true, axis=1).tolist(), mim_y)
print("Test mim accuracy:{}".format(te_mim_acc))
# Out:
# Test mim accuracy:0.625

# %%
#Evaluation accuracy for FGSM Attack
fgsm_y = []
y_true = []
for X, y in te_data:
    X_fgsm = fgsm_attack(def_model, X, y, epsilon=0.0313, from_logits=False, soft_label=True)
    y_fgsm = np.argmax(def_model(X_fgsm).numpy(), 1)
    fgsm_y.append(y_fgsm[0].tolist())
    y_true.append(y.numpy()[0].tolist())

te_fgsm_acc = accuracy_score(np.argmax(y_true, axis=1).tolist(), fgsm_y)
print("Test fgsm accuracy:{}".format(te_fgsm_acc))
# Out:
# Test fgsm accuracy:0.5625

# %% [markdown]
# The following is an exploring question with bonus points. It is great if you try to do this question, but it is **totally optional**. In this question, we will investigate a recent SOTA technique to improve the generalization ability of deep nets named *Sharpness-Aware Minimization (SAM)* ([link to the main paper](https://openreview.net/pdf?id=6Tm1mposlrM)).  Furthermore, SAM is simple and efficient technique, but roughly doubles the training time due to its required computation. If you have an idea to improve SAM, it would be a great paper to top-tier venues in machine learning and computer vision. Highly recommend to give it a try.

# %% [markdown]
# <span style="color:red">**Question 3.10**</span> (**additionally exploring question**) Read the SAM paper ([link to the main paper](https://openreview.net/pdf?id=6Tm1mposlrM)). Try to apply this techique to the best obtained model and report the results. For the purpose of implementating SAM, we can flexibly add more cells and extensions to the `model.py` file.
#
# <div style="text-align: right"> <span style="color:red">[5 points]</span> </div>

# %%
#Insert your code here. You can add more cells if necessary

# %% [markdown]
# ---
# **<div style="text-align: center"> <span style="color:black">END OF ASSIGNMENT</span> </div>**
# **<div style="text-align: center"> <span style="color:black">GOOD LUCK WITH YOUR ASSIGNMENT 1!</span> </div>**
